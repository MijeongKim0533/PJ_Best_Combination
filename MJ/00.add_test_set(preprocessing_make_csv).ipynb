# %% [markdown]
# 1. null, 이상치 제거 (z-score 그래프 보고 3, 4, 5, 6, 7) 다양한 시도 해봐야 함
# 2. 스케일링 standard, minmax, robust, maxabs + log 스케일링 다 시도해 보아야 함
# 3. 모델은 여러개 쓰지 않더라도 랜덤, xgboost, lightGBM, gradiant 시도해 보고 -> 스태킹 앙상블 사용해보기
# 4. 하이퍼 파라미터 조정하기
# 5. 생각나면 추가적으로

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
import xgboost as xgb
from sklearn.feature_selection import RFECV

# %%
df = pd.read_csv('../game_result/merged_FBREF_train_validation_set.csv')

# %%
df
# Out:
#             Date                    Team        Opponent      Referee  TY  OY  \
# 0     2018-08-10          Leicester City  Manchester Utd   A Marriner   1   2
# 1     2018-08-10          Manchester Utd  Leicester City   A Marriner   2   1
# 2     2018-08-11             Bournemouth    Cardiff City     K Friend   1   1
# 3     2018-08-11  Brighton & Hove Albion         Watford       J Moss   2   2
# 4     2018-08-11            Cardiff City     Bournemouth     K Friend   1   1
# ...          ...                     ...             ...          ...  ..  ..
# 4465  2024-04-24                 Everton       Liverpool     A Madley   0   3
# 4466  2024-04-24           Sheffield Utd  Manchester Utd  M Salisbury   1   0
# 4467  2024-04-24          Crystal Palace   Newcastle Utd    T Bramall   3   3
# 4468  2024-04-24          Manchester Utd   Sheffield Utd  M Salisbury   0   1
# 4469  2024-04-24             Bournemouth   Wolverhampton    S Attwell   1   4
#
#       TR  OR  B365TW  B365D  ...  Clean Sheet  Pass Completion % Assists  \
# 0      0   0    7.50   3.90  ...            0               79.4       0
# 1      0   0    1.57   3.90  ...            0               80.1       1
# 2      0   0    1.90   3.60  ...            1               79.0       2
# 3      0   0    3.40   3.20  ...            0               74.4       0
# 4      0   0    4.50   3.60  ...            0               58.4       0
# ...   ..  ..     ...    ...  ...          ...                ...     ...
# 4465   0   0    7.00   5.00  ...            1               63.1       1
# 4466   0   0    8.50   6.00  ...            0               72.2       1
# 4467   0   0    3.10   3.60  ...            1               74.5       2
# 4468   0   0    1.30   6.00  ...            0               87.6       3
# 4469   1   0    2.40   3.75  ...            1               71.4       0
#
#      Exp. Assisted Goals  Expected Assists  Tackles Won  \
# 0                    0.8               1.0           11
# 1                    0.7               0.3           13
# 2                    1.3               1.1            5
# 3                    0.3               0.2           11
# 4                    1.5               1.2           12
# ...                  ...               ...          ...
# 4465                 0.8               0.6            9
# 4466                 0.5               0.3            9
# 4467                 0.7               0.8           19
# 4468                 2.0               1.8            9
# 4469                 1.3               0.7           14
#
#      % of Dribblers Tackled Blocks Interceptions  Error
# 0                      21.4      8            12      0
# 1                      50.0     15            17      0
# 2                      47.1     11             4      0
# 3                      50.0     14            17      0
# 4                      47.6     16            15      0
# ...                     ...    ...           ...    ...
# 4465                   42.9     14            14      0
# 4466                   46.7     10            13      0
# 4467                   60.0     15             6      0
# 4468                   52.9      6             5      1
# 4469                   16.7     18            11      0
#
# [4470 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Team', 'Opponent', 'Referee', 'TY', 'OY', 'TR', 'OR', 'B365TW',
#        'B365D', 'B365OW', 'Season', 'Time', 'Round', 'Round.1', 'Table', 'Day',
#        'Venue', 'Result', 'Possesion', 'Aerial Duels(%)', 'GF', 'GA',
#        'Oppo. Table', 'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
#        'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
#        'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
#        '% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                      0
# Team                      0
# Opponent                  0
# Referee                   0
# TY                        0
# OY                        0
# TR                        0
# OR                        0
# B365TW                    0
# B365D                     0
# B365OW                    0
# Season                    0
# Time                      0
# Round                     0
# Round.1                   0
# Table                     0
# Day                       0
# Venue                     0
# Result                    0
# Possesion                 0
# Aerial Duels(%)           0
# GF                        0
# GA                        0
# Oppo. Table               0
# Shot on Target            0
# Shot on Target(%)         2
# Goals per Shot            2
# Expected Goals            0
# Save%                     0
# Clean Sheet               0
# Pass Completion %         0
# Assists                   0
# Exp. Assisted Goals       0
# Expected Assists          0
# Tackles Won               0
# % of Dribblers Tackled    0
# Blocks                    0
# Interceptions             0
# Error                     0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Date                      0
# Team                      0
# Opponent                  0
# Referee                   0
# TY                        0
# OY                        0
# TR                        0
# OR                        0
# B365TW                    0
# B365D                     0
# B365OW                    0
# Season                    0
# Time                      0
# Round                     0
# Round.1                   0
# Table                     0
# Day                       0
# Venue                     0
# Result                    0
# Possesion                 0
# Aerial Duels(%)           0
# GF                        0
# GA                        0
# Oppo. Table               0
# Shot on Target            0
# Shot on Target(%)         0
# Goals per Shot            0
# Expected Goals            0
# Save%                     0
# Clean Sheet               0
# Pass Completion %         0
# Assists                   0
# Exp. Assisted Goals       0
# Expected Assists          0
# Tackles Won               0
# % of Dribblers Tackled    0
# Blocks                    0
# Interceptions             0
# Error                     0
# dtype: int64

# %%
# 지금 이 데이터셋에는 감독이 없는데 club_games 데이터셋의 감독을 넣어서 모델링
# -> club_games, games dataset 가져와야 함

# %%
club_games_df = pd.read_csv('club_games.csv')

# %%
club_games_df
# Out:
#         game_id  club_id  own_goals  own_position        own_manager_name  \
# 0       2320450     1468          0           NaN       Holger Bachthaler
# 1       2320460        1          3           NaN         Jürgen Luginger
# 2       2320472     2036          4           NaN           Frank Schmidt
# 3       2321044       16          2           1.0            Jürgen Klopp
# 4       2321060       23          0          18.0    Torsten Lieberknecht
# ...         ...      ...        ...           ...                     ...
# 135511  3142950      681          0           NaN         Imanol Alguacil
# 135512  3148382      150          1           NaN           Quique Setién
# 135513  3153158      418          1           NaN         Santiago Solari
# 135514  3307741    36661          1           NaN      Aleksandr Gorshkov
# 135515  3520159    50600          0           NaN  Aleksandr Kishinevskiy
#
#         opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 0                24               2                NaN             Armin Veh
# 1                86               1                NaN            Robin Dutt
# 2                72               5                NaN     Alexander Schmidt
# 3                23               1               15.0  Torsten Lieberknecht
# 4                24               2               11.0             Armin Veh
# ...             ...             ...                ...                   ...
# 135511          150               0                NaN         Quique Setién
# 135512          714               1                NaN                  Rubi
# 135513          131               1                NaN      Ernesto Valverde
# 135514        32218               2                NaN    Viktor Antikhovich
# 135515        12060               4                NaN     Evgeniy Kharlanov
#
#        hosting  is_win
# 0         Home       0
# 1         Home       1
# 2         Home       0
# 3         Home       1
# 4         Home       0
# ...        ...     ...
# 135511    Away       0
# 135512    Away       0
# 135513    Away       0
# 135514    Away       0
# 135515    Away       0
#
# [135516 rows x 11 columns]

# %%
club_games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135516 entries, 0 to 135515
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   game_id                135516 non-null  int64
#  1   club_id                135516 non-null  int64
#  2   own_goals              135516 non-null  int64
#  3   own_position           95480 non-null   float64
#  4   own_manager_name       134026 non-null  object
#  5   opponent_id            135516 non-null  int64
#  6   opponent_goals         135516 non-null  int64
#  7   opponent_position      95480 non-null   float64
#  8   opponent_manager_name  134026 non-null  object
#  9   hosting                135516 non-null  object
#  10  is_win                 135516 non-null  int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 11.4+ MB

# %%
games_df = pd.read_csv('games.csv')

# %%
games_df
# Out:
#        game_id competition_id  season         round        date  home_club_id  \
# 0      2321044             L1    2013   2. Matchday  2013-08-18            16
# 1      2321060             L1    2013   3. Matchday  2013-08-25            23
# 2      2321086             L1    2013   6. Matchday  2013-09-21             4
# 3      2321152             L1    2013  11. Matchday  2013-11-02            44
# 4      2321205             L1    2013  17. Matchday  2013-12-21            41
# ...        ...            ...     ...           ...         ...           ...
# 67753  2700827            NL1    2016  23. Matchday  2017-02-18           383
# 67754  3852741            NL1    2022  27. Matchday  2023-04-01           467
# 67755  4097959            NL1    2023   5. Matchday  2023-09-16           383
# 67756  4098179            NL1    2023  27. Matchday  2024-03-30           467
# 67757  4225940            NLP    2023  Second Round  2023-12-20         19964
#
#        away_club_id  home_club_goals  away_club_goals  home_club_position  \
# 0                23                2                1                 1.0
# 1                24                0                2                18.0
# 2                16                1                1                15.0
# 3                33                0                2                 7.0
# 4                39                2                3                14.0
# ...             ...              ...              ...                 ...
# 67753           467                3                1                 3.0
# 67754           383                2                4                10.0
# 67755           467                4                0                 1.0
# 67756           383                3                1                 6.0
# 67757           467                1                6                 NaN
#
#        ...                stadium attendance             referee  \
# 0      ...      SIGNAL IDUNA PARK    80200.0        Peter Sippel
# 1      ...      EINTRACHT-Stadion    23325.0      Wolfgang Stark
# 2      ...    Max-Morlock-Stadion    50000.0        Knut Kircher
# 3      ...  Olympiastadion Berlin    69277.0         Günter Perl
# 4      ...       Volksparkstadion    50000.0     Bastian Dankert
# ...    ...                    ...        ...                 ...
# 67753  ...        Philips Stadion    33500.0     Jochem Kamphuis
# 67754  ...         Goffertstadion    12500.0  Edwin van de Graaf
# 67755  ...        Philips Stadion    34200.0          Joey Kooij
# 67756  ...         Goffertstadion        NaN         Bas Nijhuis
# 67757  ...      Sportpark Panhuis        NaN      Jesse Rozendal
#
#                                                      url  home_club_formation  \
# 0      https://www.transfermarkt.co.uk/borussia-dortm...              4-2-3-1
# 1      https://www.transfermarkt.co.uk/eintracht-brau...              4-3-2-1
# 2      https://www.transfermarkt.co.uk/1-fc-nuremberg...              4-2-3-1
# 3      https://www.transfermarkt.co.uk/hertha-bsc_fc-...              4-2-3-1
# 4      https://www.transfermarkt.co.uk/hamburger-sv_1...              4-2-3-1
# ...                                                  ...                  ...
# 67753  https://www.transfermarkt.co.uk/psv-eindhoven_...      4-3-3 Attacking
# 67754  https://www.transfermarkt.co.uk/nec-nijmegen_p...      4-3-3 Defending
# 67755  https://www.transfermarkt.co.uk/psv-eindhoven_...      4-3-3 Attacking
# 67756  https://www.transfermarkt.co.uk/nec-nijmegen_p...      4-3-3 Defending
# 67757  https://www.transfermarkt.co.uk/spielbericht/i...      4-3-3 Attacking
#
#       away_club_formation                                     home_club_name  \
# 0                 4-3-2-1                                  Borussia Dortmund
# 1                 4-2-3-1                             Eintracht Braunschweig
# 2                 4-2-3-1                                     1.FC Nuremberg
# 3                 4-2-3-1                                         Hertha BSC
# 4           4-4-2 Diamond                                       Hamburger SV
# ...                   ...                                                ...
# 67753               5-3-2  Eindhovense Voetbalvereniging Philips Sport Ve...
# 67754     4-3-3 Defending                      Nijmegen Eendracht Combinatie
# 67755     4-3-3 Defending  Eindhovense Voetbalvereniging Philips Sport Ve...
# 67756     4-3-3 Defending                      Nijmegen Eendracht Combinatie
# 67757     4-3-3 Defending                                                NaN
#
#                                           away_club_name aggregate  \
# 0                                 Eintracht Braunschweig       2:1
# 1                         Eintracht Frankfurt Fußball AG       0:2
# 2                                      Borussia Dortmund       1:1
# 3                                          FC Schalke 04       0:2
# 4                   1. Fußball- und Sportverein Mainz 05       2:3
# ...                                                  ...       ...
# 67753                      Nijmegen Eendracht Combinatie       3:1
# 67754  Eindhovense Voetbalvereniging Philips Sport Ve...       2:4
# 67755                      Nijmegen Eendracht Combinatie       4:0
# 67756  Eindhovense Voetbalvereniging Philips Sport Ve...       3:1
# 67757                      Nijmegen Eendracht Combinatie       1:6
#
#       competition_type
# 0      domestic_league
# 1      domestic_league
# 2      domestic_league
# 3      domestic_league
# 4      domestic_league
# ...                ...
# 67753  domestic_league
# 67754  domestic_league
# 67755  domestic_league
# 67756  domestic_league
# 67757     domestic_cup
#
# [67758 rows x 23 columns]

# %%
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67758 entries, 0 to 67757
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 67758 non-null  int64
#  1   competition_id          67758 non-null  object
#  2   season                  67758 non-null  int64
#  3   round                   67758 non-null  object
#  4   date                    67758 non-null  object
#  5   home_club_id            67758 non-null  int64
#  6   away_club_id            67758 non-null  int64
#  7   home_club_goals         67758 non-null  int64
#  8   away_club_goals         67758 non-null  int64
#  9   home_club_position      47740 non-null  float64
#  10  away_club_position      47740 non-null  float64
#  11  home_club_manager_name  67013 non-null  object
#  12  away_club_manager_name  67013 non-null  object
#  13  stadium                 67544 non-null  object
#  14  attendance              58083 non-null  float64
#  15  referee                 67159 non-null  object
#  16  url                     67758 non-null  object
#  17  home_club_formation     61254 non-null  object
#  18  away_club_formation     61401 non-null  object
#  19  home_club_name          56302 non-null  object
#  20  away_club_name          57540 non-null  object
#  21  aggregate               67758 non-null  object
#  22  competition_type        67758 non-null  object
# dtypes: float64(3), int64(6), object(14)
# memory usage: 11.9+ MB

# %%
games_df = games_df[games_df['competition_id'] == 'GB1']

# %%
games_df
# Out:
#        game_id competition_id  season         round        date  home_club_id  \
# 24     2332021            GB1    2013  17. Matchday  2013-12-21           984
# 25     2332050            GB1    2013  14. Matchday  2013-12-04           289
# 26     2332053            GB1    2013  13. Matchday  2013-11-30           379
# 27     2332188            GB1    2013  23. Matchday  2014-01-28           180
# 28     2332235            GB1    2013  23. Matchday  2014-01-28           873
# ...        ...            ...     ...           ...         ...           ...
# 67518  2872227            GB1    2017  12. Matchday  2017-11-20          1237
# 67519  2872273            GB1    2017  16. Matchday  2017-12-09           148
# 67644  4095403            GB1    2023  33. Matchday  2024-04-13          1132
# 67649  2872297            GB1    2017  19. Matchday  2017-12-23          1132
# 67718  4095328            GB1    2023  25. Matchday  2024-02-18           350
#
#        away_club_id  home_club_goals  away_club_goals  home_club_position  \
# 24             3008                1                1                16.0
# 25              631                3                4                20.0
# 26              931                3                0                15.0
# 27               11                2                2                 9.0
# 28             3008                1                0                14.0
# ...             ...              ...              ...                 ...
# 67518           512                2                2                 9.0
# 67519           512                5                1                 6.0
# 67644          1237                1                1                19.0
# 67649           148                0                3                 7.0
# 67718          1237                0                5                20.0
#
#        ...            stadium attendance          referee  \
# 24     ...      The Hawthorns    24753.0    Jonathan Moss
# 25     ...   Stadium of Light    40652.0        Phil Dowd
# 26     ...      Boleyn Ground    34946.0  Martin Atkinson
# 27     ...  St Mary's Stadium    31284.0        Lee Mason
# 28     ...      Selhurst Park    22519.0       Roger East
# ...    ...                ...        ...              ...
# 67518  ...       AMEX Stadium    29676.0        Lee Mason
# 67519  ...    Wembley Stadium    62202.0       Roger East
# 67644  ...          Turf Moor        NaN     Simon Hooper
# 67649  ...          Turf Moor    21650.0   Michael Oliver
# 67718  ...       Bramall Lane    29522.0   Stuart Attwell
#
#                                                      url  home_club_formation  \
# 24     https://www.transfermarkt.co.uk/west-bromwich-...              4-2-3-1
# 25     https://www.transfermarkt.co.uk/sunderland-afc...              4-1-4-1
# 26     https://www.transfermarkt.co.uk/west-ham-unite...              4-2-3-1
# 27     https://www.transfermarkt.co.uk/southampton-fc...              4-2-3-1
# 28     https://www.transfermarkt.co.uk/crystal-palace...       4-4-2 double 6
# ...                                                  ...                  ...
# 67518  https://www.transfermarkt.co.uk/brighton-amp-h...       4-4-2 double 6
# 67519  https://www.transfermarkt.co.uk/tottenham-hots...              4-2-3-1
# 67644  https://www.transfermarkt.co.uk/burnley-fc_bri...                4-4-2
# 67649  https://www.transfermarkt.co.uk/burnley-fc_tot...              4-2-3-1
# 67718  https://www.transfermarkt.co.uk/sheffield-unit...           3-5-2 flat
#
#       away_club_formation                          home_club_name  \
# 24                  5-3-2                    West Bromwich Albion
# 25                4-2-3-1                          Sunderland AFC
# 26                4-4-1-1           West Ham United Football Club
# 27                4-2-3-1                          Southampton FC
# 28             3-5-2 flat            Crystal Palace Football Club
# ...                   ...                                     ...
# 67518               3-5-2  Brighton and Hove Albion Football Club
# 67519               5-4-1         Tottenham Hotspur Football Club
# 67644             4-2-3-1                   Burnley Football Club
# 67649             4-2-3-1                   Burnley Football Club
# 67718             4-2-3-1          Sheffield United Football Club
#
#                                away_club_name aggregate competition_type
# 24                                  Hull City       1:1  domestic_league
# 25                      Chelsea Football Club       3:4  domestic_league
# 26                       Fulham Football Club       3:0  domestic_league
# 27                      Arsenal Football Club       2:2  domestic_league
# 28                                  Hull City       1:0  domestic_league
# ...                                       ...       ...              ...
# 67518                              Stoke City       2:2  domestic_league
# 67519                              Stoke City       5:1  domestic_league
# 67644  Brighton and Hove Albion Football Club       1:1  domestic_league
# 67649         Tottenham Hotspur Football Club       0:3  domestic_league
# 67718  Brighton and Hove Albion Football Club       0:5  domestic_league
#
# [4503 rows x 23 columns]

# %%
games_df['date'] = pd.to_datetime(games_df['date'])

# %%
games_df = games_df[games_df['date'] >= '2018-08-01']

# %%
games_df
# Out:
#        game_id competition_id  season         round       date  home_club_id  \
# 1876   3050170            GB1    2018   1. Matchday 2018-08-11          1110
# 1877   3050215            GB1    2018   5. Matchday 2018-09-15          1010
# 1878   3050250            GB1    2018   9. Matchday 2018-10-20           631
# 1879   3050264            GB1    2018  10. Matchday 2018-10-27           180
# 1880   3050336            GB1    2018  17. Matchday 2018-12-15           543
# ...        ...            ...     ...           ...        ...           ...
# 67257  3429714            GB1    2020  23. Matchday 2021-02-06          1132
# 67504  3429694            GB1    2020  21. Matchday 2021-01-31          1237
# 67512  3592240            GB1    2021  37. Matchday 2022-05-15           148
# 67644  4095403            GB1    2023  33. Matchday 2024-04-13          1132
# 67718  4095328            GB1    2023  25. Matchday 2024-02-18           350
#
#        away_club_id  home_club_goals  away_club_goals  home_club_position  \
# 1876            631                0                3                19.0
# 1877            985                1                2                 4.0
# 1878            985                2                2                 3.0
# 1879            762                0                0                16.0
# 1880            989                2                0                 7.0
# ...             ...              ...              ...                 ...
# 67257          1237                1                1                17.0
# 67504           148                1                0                17.0
# 67512          1132                1                0                 4.0
# 67644          1237                1                1                19.0
# 67718          1237                0                5                20.0
#
#        ...                    stadium attendance         referee  \
# 1876   ...       John Smith's Stadium    24121.0  Chris Kavanagh
# 1877   ...              Vicarage Road    20537.0       Mike Dean
# 1878   ...            Stamford Bridge    40721.0       Mike Dean
# 1879   ...          St Mary's Stadium    30736.0  Chris Kavanagh
# 1880   ...           Molineux Stadium    30997.0    Simon Hooper
# ...    ...                        ...        ...             ...
# 67257  ...                  Turf Moor        NaN  Anthony Taylor
# 67504  ...               AMEX Stadium        NaN    Peter Bankes
# 67512  ...  Tottenham Hotspur Stadium    61729.0    Kevin Friend
# 67644  ...                  Turf Moor        NaN    Simon Hooper
# 67718  ...               Bramall Lane    29522.0  Stuart Attwell
#
#                                                      url  home_club_formation  \
# 1876   https://www.transfermarkt.co.uk/huddersfield-t...           3-5-2 flat
# 1877   https://www.transfermarkt.co.uk/watford-fc_man...                4-4-2
# 1878   https://www.transfermarkt.co.uk/chelsea-fc_man...      4-3-3 Attacking
# 1879   https://www.transfermarkt.co.uk/southampton-fc...       4-4-2 double 6
# 1880   https://www.transfermarkt.co.uk/wolverhampton-...                3-5-2
# ...                                                  ...                  ...
# 67257  https://www.transfermarkt.co.uk/burnley-fc_bri...       4-4-2 double 6
# 67504  https://www.transfermarkt.co.uk/brighton-amp-h...              3-4-2-1
# 67512  https://www.transfermarkt.co.uk/tottenham-hots...                5-4-1
# 67644  https://www.transfermarkt.co.uk/burnley-fc_bri...                4-4-2
# 67718  https://www.transfermarkt.co.uk/sheffield-unit...           3-5-2 flat
#
#       away_club_formation                          home_club_name  \
# 1876      4-3-3 Attacking                       Huddersfield Town
# 1877              4-2-3-1                              Watford FC
# 1878      4-3-3 Attacking                   Chelsea Football Club
# 1879       4-4-2 double 6                          Southampton FC
# 1880              3-4-2-1   Wolverhampton Wanderers Football Club
# ...                   ...                                     ...
# 67257               5-3-2                   Burnley Football Club
# 67504             3-4-2-1  Brighton and Hove Albion Football Club
# 67512               5-3-2         Tottenham Hotspur Football Club
# 67644             4-2-3-1                   Burnley Football Club
# 67718             4-2-3-1          Sheffield United Football Club
#
#                                away_club_name aggregate competition_type
# 1876                    Chelsea Football Club       0:3  domestic_league
# 1877          Manchester United Football Club       1:2  domestic_league
# 1878          Manchester United Football Club       2:2  domestic_league
# 1879           Newcastle United Football Club       0:0  domestic_league
# 1880    Association Football Club Bournemouth       2:0  domestic_league
# ...                                       ...       ...              ...
# 67257  Brighton and Hove Albion Football Club       1:1  domestic_league
# 67504         Tottenham Hotspur Football Club       1:0  domestic_league
# 67512                   Burnley Football Club       1:0  domestic_league
# 67644  Brighton and Hove Albion Football Club       1:1  domestic_league
# 67718  Brighton and Hove Albion Football Club       0:5  domestic_league
#
# [2223 rows x 23 columns]

# %%
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2223 entries, 1876 to 67718
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 2223 non-null   int64
#  1   competition_id          2223 non-null   object
#  2   season                  2223 non-null   int64
#  3   round                   2223 non-null   object
#  4   date                    2223 non-null   datetime64[ns]
#  5   home_club_id            2223 non-null   int64
#  6   away_club_id            2223 non-null   int64
#  7   home_club_goals         2223 non-null   int64
#  8   away_club_goals         2223 non-null   int64
#  9   home_club_position      2223 non-null   float64
#  10  away_club_position      2223 non-null   float64
#  11  home_club_manager_name  2223 non-null   object
#  12  away_club_manager_name  2223 non-null   object
#  13  stadium                 2223 non-null   object
#  14  attendance              1759 non-null   float64
#  15  referee                 2223 non-null   object
#  16  url                     2223 non-null   object
#  17  home_club_formation     2223 non-null   object
#  18  away_club_formation     2223 non-null   object
#  19  home_club_name          2223 non-null   object
#  20  away_club_name          2223 non-null   object
#  21  aggregate               2223 non-null   object
#  22  competition_type        2223 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(6), object(13)
# memory usage: 416.8+ KB

# %%
games_df.isnull().sum()
# Out:
# game_id                     0
# competition_id              0
# season                      0
# round                       0
# date                        0
# home_club_id                0
# away_club_id                0
# home_club_goals             0
# away_club_goals             0
# home_club_position          0
# away_club_position          0
# home_club_manager_name      0
# away_club_manager_name      0
# stadium                     0
# attendance                464
# referee                     0
# url                         0
# home_club_formation         0
# away_club_formation         0
# home_club_name              0
# away_club_name              0
# aggregate                   0
# competition_type            0
# dtype: int64

# %%
club_games_df = club_games_df[club_games_df['game_id'].isin(games_df['game_id'])]

# %%
club_games_df
# Out:
#         game_id  club_id  own_goals  own_position own_manager_name  \
# 2096    3050170     1110          0          19.0     David Wagner
# 2097    3050190     1110          0          19.0     David Wagner
# 2098    3050199      603          2          16.0     Neil Warnock
# 2099    3050215     1010          1           4.0      Javi Gracia
# 2100    3050250      631          2           3.0   Maurizio Sarri
# ...         ...      ...        ...           ...              ...
# 135489  3429732      350          0          20.0     Chris Wilder
# 135490  3429776      399          2          11.0   Marcelo Bielsa
# 135492  3592178       31          2           2.0     Jürgen Klopp
# 135495  4095319     1148          2          14.0     Thomas Frank
# 135496  3219126     1010          1          17.0    Nigel Pearson
#
#         opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 2096            631               3                2.0        Maurizio Sarri
# 2097            603               0               15.0          Neil Warnock
# 2098             11               3                9.0            Unai Emery
# 2099            985               2                8.0         José Mourinho
# 2100            985               2               10.0         José Mourinho
# ...             ...             ...                ...                   ...
# 135489          379               3                5.0           David Moyes
# 135490          931               1               18.0          Scott Parker
# 135492          405               1               15.0        Steven Gerrard
# 135495          543               0               11.0           Gary O'Neil
# 135496          379               3               15.0           David Moyes
#
#        hosting  is_win
# 2096      Home       0
# 2097      Home       0
# 2098      Home       0
# 2099      Home       0
# 2100      Home       0
# ...        ...     ...
# 135489    Away       0
# 135490    Away       1
# 135492    Away       1
# 135495    Away       1
# 135496    Away       0
#
# [4446 rows x 11 columns]

# %%
# club_games_df에 date가 필요해서 merge함

merged_df1 = pd.merge(games_df[['game_id', 'date']], club_games_df, on='game_id', how='right')

# %%
merged_df1.sort_values('game_id')
# Out:
#       game_id       date  club_id  own_goals  own_position  \
# 933   3050167 2018-08-12       11          0          15.0
# 3156  3050167 2018-08-12      281          2           3.0
# 4265  3050168 2018-08-11      603          0          17.0
# 2042  3050168 2018-08-11      989          2           5.0
# 934   3050169 2018-08-11      931          0          18.0
# ...       ...        ...      ...        ...           ...
# 912   4095407 2024-04-13      762          4           6.0
# 2379  4095408 2024-04-13      543          2          11.0
# 156   4095408 2024-04-13      703          2          17.0
# 4426  4095409 2024-04-14      931          2          12.0
# 2203  4095409 2024-04-14      379          0           8.0
#
#          own_manager_name  opponent_id  opponent_goals  opponent_position  \
# 933            Unai Emery          281               2                3.0
# 3156        Pep Guardiola           11               0               15.0
# 4265         Neil Warnock          989               2                5.0
# 2042           Eddie Howe          603               0               17.0
# 934     Slavisa Jokanovic          873               2                4.0
# ...                   ...          ...             ...                ...
# 912            Eddie Howe          148               0                5.0
# 2379          Gary O'Neil          703               2               17.0
# 156   Nuno Espírito Santo          543               2               11.0
# 4426          Marco Silva          379               0                8.0
# 2203          David Moyes          931               2               12.0
#
#      opponent_manager_name hosting  is_win
# 933          Pep Guardiola    Home       0
# 3156            Unai Emery    Away       1
# 4265            Eddie Howe    Away       0
# 2042          Neil Warnock    Home       1
# 934            Roy Hodgson    Home       0
# ...                    ...     ...     ...
# 912       Ange Postecoglou    Home       1
# 2379   Nuno Espírito Santo    Away       0
# 156            Gary O'Neil    Home       0
# 4426           David Moyes    Away       1
# 2203           Marco Silva    Home       0
#
# [4446 rows x 12 columns]

# %%
merged_home_df = merged_df1[merged_df1['hosting'] == 'Home']

# %%
merged_away_df = merged_df1[merged_df1['hosting'] == 'Away']

# %%
home_game_df = pd.merge(merged_home_df, games_df[['game_id', 'home_club_name']], on='game_id')

# %%
home_game_df = home_game_df.sort_values('game_id')

# %%
new_column_names = {'home_club_name': 'club_name'}
home_game_df = home_game_df.rename(columns=new_column_names)

# %%
away_game_df = pd.merge(merged_away_df, games_df[['game_id', 'away_club_name']], on='game_id')

# %%
away_game_df = away_game_df.sort_values('game_id')

# %%
new_column_names = {'away_club_name': 'club_name'}
away_game_df = away_game_df.rename(columns=new_column_names)

# %%
m_merged_df = pd.concat([home_game_df, away_game_df], axis=0).sort_values('game_id')

# %%
# 이 df가 games, club_games 합친 df
m_merged_df
# Out:
#       game_id       date  club_id  own_goals  own_position  \
# 933   3050167 2018-08-12       11          0          15.0
# 933   3050167 2018-08-12      281          2           3.0
# 2042  3050168 2018-08-11      603          0          17.0
# 2042  3050168 2018-08-11      989          2           5.0
# 934   3050169 2018-08-11      931          0          18.0
# ...       ...        ...      ...        ...           ...
# 912   4095407 2024-04-13      762          4           6.0
# 156   4095408 2024-04-13      543          2          11.0
# 156   4095408 2024-04-13      703          2          17.0
# 2203  4095409 2024-04-14      379          0           8.0
# 2203  4095409 2024-04-14      931          2          12.0
#
#          own_manager_name  opponent_id  opponent_goals  opponent_position  \
# 933            Unai Emery          281               2                3.0
# 933         Pep Guardiola           11               0               15.0
# 2042         Neil Warnock          989               2                5.0
# 2042           Eddie Howe          603               0               17.0
# 934     Slavisa Jokanovic          873               2                4.0
# ...                   ...          ...             ...                ...
# 912            Eddie Howe          148               0                5.0
# 156           Gary O'Neil          703               2               17.0
# 156   Nuno Espírito Santo          543               2               11.0
# 2203          David Moyes          931               2               12.0
# 2203          Marco Silva          379               0                8.0
#
#      opponent_manager_name hosting  is_win  \
# 933          Pep Guardiola    Home       0
# 933             Unai Emery    Away       1
# 2042            Eddie Howe    Away       0
# 2042          Neil Warnock    Home       1
# 934            Roy Hodgson    Home       0
# ...                    ...     ...     ...
# 912       Ange Postecoglou    Home       1
# 156    Nuno Espírito Santo    Away       0
# 156            Gary O'Neil    Home       0
# 2203           Marco Silva    Home       0
# 2203           David Moyes    Away       1
#
#                                   club_name
# 933                   Arsenal Football Club
# 933           Manchester City Football Club
# 2042                           Cardiff City
# 2042  Association Football Club Bournemouth
# 934                    Fulham Football Club
# ...                                     ...
# 912          Newcastle United Football Club
# 156   Wolverhampton Wanderers Football Club
# 156         Nottingham Forest Football Club
# 2203          West Ham United Football Club
# 2203                   Fulham Football Club
#
# [4446 rows x 13 columns]

# %%
dropped_df = df.drop(['Season', 'Time', 'Round', 'Round.1', 'Day'], axis=1)

# %%
dropped_df.columns
# Out:
# Index(['Date', 'Team', 'Opponent', 'Referee', 'TY', 'OY', 'TR', 'OR', 'B365TW',
#        'B365D', 'B365OW', 'Table', 'Venue', 'Result', 'Possesion',
#        'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table', 'Shot on Target',
#        'Shot on Target(%)', 'Goals per Shot', 'Expected Goals', 'Save%',
#        'Clean Sheet', 'Pass Completion %', 'Assists', 'Exp. Assisted Goals',
#        'Expected Assists', 'Tackles Won', '% of Dribblers Tackled', 'Blocks',
#        'Interceptions', 'Error'],
#       dtype='object')

# %%
# df 와 merge하기 위해서 club이름을 다시 설정

# %%
name_mapping = {
    'Arsenal Football Club': 'Arsenal', 
    'Manchester City Football Club': 'Manchester City',
    'Cardiff City': 'Cardiff City', 
    'Association Football Club Bournemouth': 'Bournemouth',
    'Fulham Football Club': 'Fulham', 
    'Crystal Palace Football Club': 'Crystal Palace',
    'Huddersfield Town': 'Huddersfield', 
    'Chelsea Football Club': 'Chelsea',
    'West Ham United Football Club': 'West Ham', 
    'Liverpool Football Club': 'Liverpool',
    'Manchester United Football Club': 'Manchester Utd', 
    'Leicester City': 'Leicester City',
    'Newcastle United Football Club': 'Newcastle Utd',
    'Tottenham Hotspur Football Club': 'Tottenham', 
    'Burnley Football Club': 'Burnley',
    'Southampton FC': 'Southampton', 
    'Watford FC': 'Watford',
    'Brighton and Hove Albion Football Club': 'Brighton & Hove Albion',
    'Wolverhampton Wanderers Football Club': 'Wolverhampton', 
    'Everton Football Club': 'Everton',
    'Norwich City': 'Norwich City', 
    'Sheffield United Football Club': 'Sheffield Utd',
    'Aston Villa Football Club': 'Aston Villa', 
    'Leeds United': 'Leeds United',
    'West Bromwich Albion': 'West Bromwich Albion', 
    'Brentford Football Club': 'Brentford',
    'Nottingham Forest Football Club': 'Nottingham Forest', 
    'Luton Town Football Club': 'Luton Town'
}

# %%
m_merged_df['club_name'] = m_merged_df['club_name'].replace(name_mapping)

# %%
m_merged_df
# Out:
#       game_id       date  club_id  own_goals  own_position  \
# 933   3050167 2018-08-12       11          0          15.0
# 933   3050167 2018-08-12      281          2           3.0
# 2042  3050168 2018-08-11      603          0          17.0
# 2042  3050168 2018-08-11      989          2           5.0
# 934   3050169 2018-08-11      931          0          18.0
# ...       ...        ...      ...        ...           ...
# 912   4095407 2024-04-13      762          4           6.0
# 156   4095408 2024-04-13      543          2          11.0
# 156   4095408 2024-04-13      703          2          17.0
# 2203  4095409 2024-04-14      379          0           8.0
# 2203  4095409 2024-04-14      931          2          12.0
#
#          own_manager_name  opponent_id  opponent_goals  opponent_position  \
# 933            Unai Emery          281               2                3.0
# 933         Pep Guardiola           11               0               15.0
# 2042         Neil Warnock          989               2                5.0
# 2042           Eddie Howe          603               0               17.0
# 934     Slavisa Jokanovic          873               2                4.0
# ...                   ...          ...             ...                ...
# 912            Eddie Howe          148               0                5.0
# 156           Gary O'Neil          703               2               17.0
# 156   Nuno Espírito Santo          543               2               11.0
# 2203          David Moyes          931               2               12.0
# 2203          Marco Silva          379               0                8.0
#
#      opponent_manager_name hosting  is_win          club_name
# 933          Pep Guardiola    Home       0            Arsenal
# 933             Unai Emery    Away       1    Manchester City
# 2042            Eddie Howe    Away       0       Cardiff City
# 2042          Neil Warnock    Home       1        Bournemouth
# 934            Roy Hodgson    Home       0             Fulham
# ...                    ...     ...     ...                ...
# 912       Ange Postecoglou    Home       1      Newcastle Utd
# 156    Nuno Espírito Santo    Away       0      Wolverhampton
# 156            Gary O'Neil    Home       0  Nottingham Forest
# 2203           Marco Silva    Home       0           West Ham
# 2203           David Moyes    Away       1             Fulham
#
# [4446 rows x 13 columns]

# %%
# 내가 지금까지 club_games랑 games df를 전처리한 건 df DataFrame에 감독이름을 추가하기 위해서

# %%
# 다음은 df dataframe 정리하기

# %%
# 배팅 정보는 확률로 변경

# %%
dropped_df['B365TW'] = (1/dropped_df['B365TW'])*100

# %%
dropped_df['B365D'] = (1/dropped_df['B365D'])*100

# %%
dropped_df['B365OW'] = (1/dropped_df['B365OW'])*100

# %%
dropped_df.columns
# Out:
# Index(['Date', 'Team', 'Opponent', 'Referee', 'TY', 'OY', 'TR', 'OR', 'B365TW',
#        'B365D', 'B365OW', 'Table', 'Venue', 'Result', 'Possesion',
#        'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table', 'Shot on Target',
#        'Shot on Target(%)', 'Goals per Shot', 'Expected Goals', 'Save%',
#        'Clean Sheet', 'Pass Completion %', 'Assists', 'Exp. Assisted Goals',
#        'Expected Assists', 'Tackles Won', '% of Dribblers Tackled', 'Blocks',
#        'Interceptions', 'Error'],
#       dtype='object')

# %%
dropped_df.head()
# Out:
#          Date                    Team        Opponent     Referee  TY  OY  TR  \
# 0  2018-08-10          Leicester City  Manchester Utd  A Marriner   1   2   0
# 1  2018-08-10          Manchester Utd  Leicester City  A Marriner   2   1   0
# 2  2018-08-11             Bournemouth    Cardiff City    K Friend   1   1   0
# 3  2018-08-11  Brighton & Hove Albion         Watford      J Moss   2   2   0
# 4  2018-08-11            Cardiff City     Bournemouth    K Friend   1   1   0
#
#    OR     B365TW      B365D  ...  Clean Sheet  Pass Completion % Assists  \
# 0   0  13.333333  25.641026  ...            0               79.4       0
# 1   0  63.694268  25.641026  ...            0               80.1       1
# 2   0  52.631579  27.777778  ...            1               79.0       2
# 3   0  29.411765  31.250000  ...            0               74.4       0
# 4   0  22.222222  27.777778  ...            0               58.4       0
#
#   Exp. Assisted Goals  Expected Assists  Tackles Won  % of Dribblers Tackled  \
# 0                 0.8               1.0           11                    21.4
# 1                 0.7               0.3           13                    50.0
# 2                 1.3               1.1            5                    47.1
# 3                 0.3               0.2           11                    50.0
# 4                 1.5               1.2           12                    47.6
#
#    Blocks  Interceptions  Error
# 0       8             12      0
# 1      15             17      0
# 2      11              4      0
# 3      14             17      0
# 4      16             15      0
#
# [5 rows x 34 columns]

# %%
dropped_df['Date'] = pd.to_datetime(dropped_df['Date'])

# %%
master_df = pd.merge(m_merged_df[['game_id', 'date', 'club_name', 'club_id', 'opponent_id', 'own_manager_name', 'opponent_manager_name']], dropped_df, \
         left_on=['date', 'club_name'], right_on=['Date', 'Team'])

# %%
master_df = master_df.drop(['date', 'club_name'], axis=1)

# %%
master_df.columns
# Out:
# Index(['game_id', 'club_id', 'opponent_id', 'own_manager_name',
#        'opponent_manager_name', 'Date', 'Team', 'Opponent', 'Referee', 'TY',
#        'OY', 'TR', 'OR', 'B365TW', 'B365D', 'B365OW', 'Table', 'Venue',
#        'Result', 'Possesion', 'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table',
#        'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
#        'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
#        'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
#        '% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error'],
#       dtype='object')

# %%
new_column_order = ['game_id', 'Date', 'Team', 'Opponent', 'club_id', 'opponent_id', 'own_manager_name', 'opponent_manager_name',
       'Referee', 'TY', 'OY', 'TR', 'OR', 'B365TW', 'B365D',
       'B365OW', 'Table', 'Venue', 'Result', 'Possesion', 'Aerial Duels(%)',
       'GF', 'GA', 'Oppo. Table', 'Shot on Target', 'Shot on Target(%)',
       'Goals per Shot', 'Expected Goals', 'Save%', 'Clean Sheet',
       'Pass Completion %', 'Assists', 'Exp. Assisted Goals',
       'Expected Assists', 'Tackles Won', '% of Dribblers Tackled', 'Blocks',
       'Interceptions', 'Error']

# %%
master_df
# Out:
#       game_id  club_id  opponent_id   own_manager_name opponent_manager_name  \
# 0     3050167       11          281         Unai Emery         Pep Guardiola
# 1     3050167      281           11      Pep Guardiola            Unai Emery
# 2     3050168      603          989       Neil Warnock            Eddie Howe
# 3     3050168      989          603         Eddie Howe          Neil Warnock
# 4     3050169      931          873  Slavisa Jokanovic           Roy Hodgson
# ...       ...      ...          ...                ...                   ...
# 4427  4095402     1148          350       Thomas Frank          Chris Wilder
# 4428  4095403     1237         1132   Roberto De Zerbi       Vincent Kompany
# 4429  4095403     1132         1237    Vincent Kompany      Roberto De Zerbi
# 4430  4095406     1031          281        Rob Edwards         Pep Guardiola
# 4431  4095409      379          931        David Moyes           Marco Silva
#
#            Date                    Team                Opponent    Referee  \
# 0    2018-08-12                 Arsenal         Manchester City   M Oliver
# 1    2018-08-12         Manchester City                 Arsenal   M Oliver
# 2    2018-08-11            Cardiff City             Bournemouth   K Friend
# 3    2018-08-11             Bournemouth            Cardiff City   K Friend
# 4    2018-08-11                  Fulham          Crystal Palace     M Dean
# ...         ...                     ...                     ...        ...
# 4427 2024-04-13               Brentford           Sheffield Utd  S Barrott
# 4428 2024-04-13  Brighton & Hove Albion                 Burnley   S Hooper
# 4429 2024-04-13                 Burnley  Brighton & Hove Albion   S Hooper
# 4430 2024-04-13              Luton Town         Manchester City   J Brooks
# 4431 2024-04-14                West Ham                  Fulham  S Attwell
#
#       TY  ...  Clean Sheet  Pass Completion %  Assists  Exp. Assisted Goals  \
# 0      2  ...            0               77.1        0                  0.5
# 1      2  ...            1               81.9        2                  0.5
# 2      1  ...            0               58.4        0                  1.5
# 3      1  ...            1               79.0        2                  1.3
# 4      1  ...            0               85.2        0                  0.5
# ...   ..  ...          ...                ...      ...                  ...
# 4427   3  ...            1               74.4        1                  1.0
# 4428   1  ...            0               84.2        0                  0.5
# 4429   1  ...            0               79.7        0                  1.5
# 4430   1  ...            0               76.0        0                  0.3
# 4431   1  ...            0               82.4        0                  0.6
#
#       Expected Assists  Tackles Won  % of Dribblers Tackled Blocks  \
# 0                  0.6           14                    40.0     13
# 1                  0.4            5                    28.6     14
# 2                  1.2           12                    47.6     16
# 3                  1.1            5                    47.1     11
# 4                  0.7           19                    42.9      5
# ...                ...          ...                     ...    ...
# 4427               1.1            8                    21.7     15
# 4428               0.9            8                    64.7     11
# 4429               1.5            6                    61.9     15
# 4430               0.1            7                    44.4     18
# 4431               0.7            8                    53.3     10
#
#      Interceptions  Error
# 0               12      1
# 1               12      1
# 2               15      0
# 3                4      0
# 4               15      1
# ...            ...    ...
# 4427            14      0
# 4428             5      1
# 4429             5      1
# 4430             8      0
# 4431             7      3
#
# [4432 rows x 39 columns]

# %%
master_df = master_df[new_column_order]

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4432 entries, 0 to 4431
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 4432 non-null   int64
#  1   Date                    4432 non-null   datetime64[ns]
#  2   Team                    4432 non-null   object
#  3   Opponent                4432 non-null   object
#  4   club_id                 4432 non-null   int64
#  5   opponent_id             4432 non-null   int64
#  6   own_manager_name        4432 non-null   object
#  7   opponent_manager_name   4432 non-null   object
#  8   Referee                 4432 non-null   object
#  9   TY                      4432 non-null   int64
#  10  OY                      4432 non-null   int64
#  11  TR                      4432 non-null   int64
#  12  OR                      4432 non-null   int64
#  13  B365TW                  4432 non-null   float64
#  14  B365D                   4432 non-null   float64
#  15  B365OW                  4432 non-null   float64
#  16  Table                   4432 non-null   int64
#  17  Venue                   4432 non-null   object
#  18  Result                  4432 non-null   object
#  19  Possesion               4432 non-null   int64
#  20  Aerial Duels(%)         4432 non-null   float64
#  21  GF                      4432 non-null   int64
#  22  GA                      4432 non-null   float64
#  23  Oppo. Table             4432 non-null   int64
#  24  Shot on Target          4432 non-null   int64
#  25  Shot on Target(%)       4432 non-null   float64
#  26  Goals per Shot          4432 non-null   float64
#  27  Expected Goals          4432 non-null   float64
#  28  Save%                   4432 non-null   float64
#  29  Clean Sheet             4432 non-null   int64
#  30  Pass Completion %       4432 non-null   float64
#  31  Assists                 4432 non-null   int64
#  32  Exp. Assisted Goals     4432 non-null   float64
#  33  Expected Assists        4432 non-null   float64
#  34  Tackles Won             4432 non-null   int64
#  35  % of Dribblers Tackled  4432 non-null   float64
#  36  Blocks                  4432 non-null   int64
#  37  Interceptions           4432 non-null   int64
#  38  Error                   4432 non-null   int64
# dtypes: datetime64[ns](1), float64(13), int64(18), object(7)
# memory usage: 1.3+ MB

# %%
--------------

# %%
# master_df 에 더해서

# %%
club_value_by_game = pd.read_csv('mean_value_by_game(train+validation).csv')

# %%
master_df.head()
# Out:
#    game_id       Date             Team         Opponent  club_id  opponent_id  \
# 0  3050167 2018-08-12          Arsenal  Manchester City       11          281
# 1  3050167 2018-08-12  Manchester City          Arsenal      281           11
# 2  3050168 2018-08-11     Cardiff City      Bournemouth      603          989
# 3  3050168 2018-08-11      Bournemouth     Cardiff City      989          603
# 4  3050169 2018-08-11           Fulham   Crystal Palace      931          873
#
#     own_manager_name opponent_manager_name   Referee  TY  ...  Clean Sheet  \
# 0         Unai Emery         Pep Guardiola  M Oliver   2  ...            0
# 1      Pep Guardiola            Unai Emery  M Oliver   2  ...            1
# 2       Neil Warnock            Eddie Howe  K Friend   1  ...            0
# 3         Eddie Howe          Neil Warnock  K Friend   1  ...            1
# 4  Slavisa Jokanovic           Roy Hodgson    M Dean   1  ...            0
#
#    Pass Completion %  Assists  Exp. Assisted Goals  Expected Assists  \
# 0               77.1        0                  0.5               0.6
# 1               81.9        2                  0.5               0.4
# 2               58.4        0                  1.5               1.2
# 3               79.0        2                  1.3               1.1
# 4               85.2        0                  0.5               0.7
#
#    Tackles Won  % of Dribblers Tackled Blocks Interceptions  Error
# 0           14                    40.0     13            12      1
# 1            5                    28.6     14            12      1
# 2           12                    47.6     16            15      0
# 3            5                    47.1     11             4      0
# 4           19                    42.9      5            15      1
#
# [5 rows x 39 columns]

# %%
club_value_by_game.head()
# Out:
#    game_id  player_club_id  market_value_in_eur
# 0  3050167              11         3.064286e+07
# 1  3050167             281         6.357143e+07
# 2  3050168             603         2.196429e+06
# 3  3050168             989         6.035714e+06
# 4  3050169             873         1.117857e+07

# %%
master_df
# Out:
#       game_id       Date                    Team                Opponent  \
# 0     3050167 2018-08-12                 Arsenal         Manchester City
# 1     3050167 2018-08-12         Manchester City                 Arsenal
# 2     3050168 2018-08-11            Cardiff City             Bournemouth
# 3     3050168 2018-08-11             Bournemouth            Cardiff City
# 4     3050169 2018-08-11                  Fulham          Crystal Palace
# ...       ...        ...                     ...                     ...
# 4427  4095402 2024-04-13               Brentford           Sheffield Utd
# 4428  4095403 2024-04-13  Brighton & Hove Albion                 Burnley
# 4429  4095403 2024-04-13                 Burnley  Brighton & Hove Albion
# 4430  4095406 2024-04-13              Luton Town         Manchester City
# 4431  4095409 2024-04-14                West Ham                  Fulham
#
#       club_id  opponent_id   own_manager_name opponent_manager_name  \
# 0          11          281         Unai Emery         Pep Guardiola
# 1         281           11      Pep Guardiola            Unai Emery
# 2         603          989       Neil Warnock            Eddie Howe
# 3         989          603         Eddie Howe          Neil Warnock
# 4         931          873  Slavisa Jokanovic           Roy Hodgson
# ...       ...          ...                ...                   ...
# 4427     1148          350       Thomas Frank          Chris Wilder
# 4428     1237         1132   Roberto De Zerbi       Vincent Kompany
# 4429     1132         1237    Vincent Kompany      Roberto De Zerbi
# 4430     1031          281        Rob Edwards         Pep Guardiola
# 4431      379          931        David Moyes           Marco Silva
#
#         Referee  TY  ...  Clean Sheet  Pass Completion %  Assists  \
# 0      M Oliver   2  ...            0               77.1        0
# 1      M Oliver   2  ...            1               81.9        2
# 2      K Friend   1  ...            0               58.4        0
# 3      K Friend   1  ...            1               79.0        2
# 4        M Dean   1  ...            0               85.2        0
# ...         ...  ..  ...          ...                ...      ...
# 4427  S Barrott   3  ...            1               74.4        1
# 4428   S Hooper   1  ...            0               84.2        0
# 4429   S Hooper   1  ...            0               79.7        0
# 4430   J Brooks   1  ...            0               76.0        0
# 4431  S Attwell   1  ...            0               82.4        0
#
#       Exp. Assisted Goals  Expected Assists  Tackles Won  \
# 0                     0.5               0.6           14
# 1                     0.5               0.4            5
# 2                     1.5               1.2           12
# 3                     1.3               1.1            5
# 4                     0.5               0.7           19
# ...                   ...               ...          ...
# 4427                  1.0               1.1            8
# 4428                  0.5               0.9            8
# 4429                  1.5               1.5            6
# 4430                  0.3               0.1            7
# 4431                  0.6               0.7            8
#
#       % of Dribblers Tackled Blocks Interceptions  Error
# 0                       40.0     13            12      1
# 1                       28.6     14            12      1
# 2                       47.6     16            15      0
# 3                       47.1     11             4      0
# 4                       42.9      5            15      1
# ...                      ...    ...           ...    ...
# 4427                    21.7     15            14      0
# 4428                    64.7     11             5      1
# 4429                    61.9     15             5      1
# 4430                    44.4     18             8      0
# 4431                    53.3     10             7      3
#
# [4432 rows x 39 columns]

# %%
club_value_by_game
# Out:
#       game_id  player_club_id  market_value_in_eur
# 0     3050167              11         3.064286e+07
# 1     3050167             281         6.357143e+07
# 2     3050168             603         2.196429e+06
# 3     3050168             989         6.035714e+06
# 4     3050169             873         1.117857e+07
# ...       ...             ...                  ...
# 4441  4095407             762         2.476000e+07
# 4442  4095408             543         1.526667e+07
# 4443  4095408             703         1.553333e+07
# 4444  4095409             379         2.371333e+07
# 4445  4095409             931         1.781250e+07
#
# [4446 rows x 3 columns]

# %%
master_df = pd.merge(master_df, club_value_by_game, left_on=['game_id', 'club_id'], right_on=['game_id', 'player_club_id'])

# %%
master_df
# Out:
#       game_id       Date                    Team                Opponent  \
# 0     3050167 2018-08-12                 Arsenal         Manchester City
# 1     3050167 2018-08-12         Manchester City                 Arsenal
# 2     3050168 2018-08-11            Cardiff City             Bournemouth
# 3     3050168 2018-08-11             Bournemouth            Cardiff City
# 4     3050169 2018-08-11                  Fulham          Crystal Palace
# ...       ...        ...                     ...                     ...
# 4427  4095402 2024-04-13               Brentford           Sheffield Utd
# 4428  4095403 2024-04-13  Brighton & Hove Albion                 Burnley
# 4429  4095403 2024-04-13                 Burnley  Brighton & Hove Albion
# 4430  4095406 2024-04-13              Luton Town         Manchester City
# 4431  4095409 2024-04-14                West Ham                  Fulham
#
#       club_id  opponent_id   own_manager_name opponent_manager_name  \
# 0          11          281         Unai Emery         Pep Guardiola
# 1         281           11      Pep Guardiola            Unai Emery
# 2         603          989       Neil Warnock            Eddie Howe
# 3         989          603         Eddie Howe          Neil Warnock
# 4         931          873  Slavisa Jokanovic           Roy Hodgson
# ...       ...          ...                ...                   ...
# 4427     1148          350       Thomas Frank          Chris Wilder
# 4428     1237         1132   Roberto De Zerbi       Vincent Kompany
# 4429     1132         1237    Vincent Kompany      Roberto De Zerbi
# 4430     1031          281        Rob Edwards         Pep Guardiola
# 4431      379          931        David Moyes           Marco Silva
#
#         Referee  TY  ...  Assists  Exp. Assisted Goals  Expected Assists  \
# 0      M Oliver   2  ...        0                  0.5               0.6
# 1      M Oliver   2  ...        2                  0.5               0.4
# 2      K Friend   1  ...        0                  1.5               1.2
# 3      K Friend   1  ...        2                  1.3               1.1
# 4        M Dean   1  ...        0                  0.5               0.7
# ...         ...  ..  ...      ...                  ...               ...
# 4427  S Barrott   3  ...        1                  1.0               1.1
# 4428   S Hooper   1  ...        0                  0.5               0.9
# 4429   S Hooper   1  ...        0                  1.5               1.5
# 4430   J Brooks   1  ...        0                  0.3               0.1
# 4431  S Attwell   1  ...        0                  0.6               0.7
#
#       Tackles Won  % of Dribblers Tackled  Blocks  Interceptions Error  \
# 0              14                    40.0      13             12     1
# 1               5                    28.6      14             12     1
# 2              12                    47.6      16             15     0
# 3               5                    47.1      11              4     0
# 4              19                    42.9       5             15     1
# ...           ...                     ...     ...            ...   ...
# 4427            8                    21.7      15             14     0
# 4428            8                    64.7      11              5     1
# 4429            6                    61.9      15              5     1
# 4430            7                    44.4      18              8     0
# 4431            8                    53.3      10              7     3
#
#      player_club_id  market_value_in_eur
# 0                11         3.064286e+07
# 1               281         6.357143e+07
# 2               603         2.196429e+06
# 3               989         6.035714e+06
# 4               931         1.060714e+07
# ...             ...                  ...
# 4427           1148         1.618750e+07
# 4428           1237         1.813333e+07
# 4429           1132         9.333333e+06
# 4430           1031         3.484615e+06
# 4431            379         2.371333e+07
#
# [4432 rows x 41 columns]

# %%
master_df.columns
# Out:
# Index(['game_id', 'Date', 'Team', 'Opponent', 'club_id', 'opponent_id',
#        'own_manager_name', 'opponent_manager_name', 'Referee', 'TY', 'OY',
#        'TR', 'OR', 'B365TW', 'B365D', 'B365OW', 'Table', 'Venue', 'Result',
#        'Possesion', 'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table',
#        'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
#        'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
#        'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
#        '% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error',
#        'player_club_id', 'market_value_in_eur'],
#       dtype='object')

# %%
master_df = master_df.drop('player_club_id', axis=1)

# %%
master_df.columns
# Out:
# Index(['game_id', 'Date', 'Team', 'Opponent', 'club_id', 'opponent_id',
#        'own_manager_name', 'opponent_manager_name', 'Referee', 'TY', 'OY',
#        'TR', 'OR', 'B365TW', 'B365D', 'B365OW', 'Table', 'Venue', 'Result',
#        'Possesion', 'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table',
#        'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
#        'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
#        'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
#        '% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error',
#        'market_value_in_eur'],
#       dtype='object')

# %%
master_df.isnull().sum()
# Out:
# game_id                   0
# Date                      0
# Team                      0
# Opponent                  0
# club_id                   0
# opponent_id               0
# own_manager_name          0
# opponent_manager_name     0
# Referee                   0
# TY                        0
# OY                        0
# TR                        0
# OR                        0
# B365TW                    0
# B365D                     0
# B365OW                    0
# Table                     0
# Venue                     0
# Result                    0
# Possesion                 0
# Aerial Duels(%)           0
# GF                        0
# GA                        0
# Oppo. Table               0
# Shot on Target            0
# Shot on Target(%)         0
# Goals per Shot            0
# Expected Goals            0
# Save%                     0
# Clean Sheet               0
# Pass Completion %         0
# Assists                   0
# Exp. Assisted Goals       0
# Expected Assists          0
# Tackles Won               0
# % of Dribblers Tackled    0
# Blocks                    0
# Interceptions             0
# Error                     0
# market_value_in_eur       0
# dtype: int64

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4432 entries, 0 to 4431
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 4432 non-null   int64
#  1   Date                    4432 non-null   datetime64[ns]
#  2   Team                    4432 non-null   object
#  3   Opponent                4432 non-null   object
#  4   club_id                 4432 non-null   int64
#  5   opponent_id             4432 non-null   int64
#  6   own_manager_name        4432 non-null   object
#  7   opponent_manager_name   4432 non-null   object
#  8   Referee                 4432 non-null   object
#  9   TY                      4432 non-null   int64
#  10  OY                      4432 non-null   int64
#  11  TR                      4432 non-null   int64
#  12  OR                      4432 non-null   int64
#  13  B365TW                  4432 non-null   float64
#  14  B365D                   4432 non-null   float64
#  15  B365OW                  4432 non-null   float64
#  16  Table                   4432 non-null   int64
#  17  Venue                   4432 non-null   object
#  18  Result                  4432 non-null   object
#  19  Possesion               4432 non-null   int64
#  20  Aerial Duels(%)         4432 non-null   float64
#  21  GF                      4432 non-null   int64
#  22  GA                      4432 non-null   float64
#  23  Oppo. Table             4432 non-null   int64
#  24  Shot on Target          4432 non-null   int64
#  25  Shot on Target(%)       4432 non-null   float64
#  26  Goals per Shot          4432 non-null   float64
#  27  Expected Goals          4432 non-null   float64
#  28  Save%                   4432 non-null   float64
#  29  Clean Sheet             4432 non-null   int64
#  30  Pass Completion %       4432 non-null   float64
#  31  Assists                 4432 non-null   int64
#  32  Exp. Assisted Goals     4432 non-null   float64
#  33  Expected Assists        4432 non-null   float64
#  34  Tackles Won             4432 non-null   int64
#  35  % of Dribblers Tackled  4432 non-null   float64
#  36  Blocks                  4432 non-null   int64
#  37  Interceptions           4432 non-null   int64
#  38  Error                   4432 non-null   int64
#  39  market_value_in_eur     4432 non-null   float64
# dtypes: datetime64[ns](1), float64(14), int64(18), object(7)
# memory usage: 1.4+ MB

# %%
master_df
# Out:
#       game_id       Date                    Team                Opponent  \
# 0     3050167 2018-08-12                 Arsenal         Manchester City
# 1     3050167 2018-08-12         Manchester City                 Arsenal
# 2     3050168 2018-08-11            Cardiff City             Bournemouth
# 3     3050168 2018-08-11             Bournemouth            Cardiff City
# 4     3050169 2018-08-11                  Fulham          Crystal Palace
# ...       ...        ...                     ...                     ...
# 4427  4095402 2024-04-13               Brentford           Sheffield Utd
# 4428  4095403 2024-04-13  Brighton & Hove Albion                 Burnley
# 4429  4095403 2024-04-13                 Burnley  Brighton & Hove Albion
# 4430  4095406 2024-04-13              Luton Town         Manchester City
# 4431  4095409 2024-04-14                West Ham                  Fulham
#
#       club_id  opponent_id   own_manager_name opponent_manager_name  \
# 0          11          281         Unai Emery         Pep Guardiola
# 1         281           11      Pep Guardiola            Unai Emery
# 2         603          989       Neil Warnock            Eddie Howe
# 3         989          603         Eddie Howe          Neil Warnock
# 4         931          873  Slavisa Jokanovic           Roy Hodgson
# ...       ...          ...                ...                   ...
# 4427     1148          350       Thomas Frank          Chris Wilder
# 4428     1237         1132   Roberto De Zerbi       Vincent Kompany
# 4429     1132         1237    Vincent Kompany      Roberto De Zerbi
# 4430     1031          281        Rob Edwards         Pep Guardiola
# 4431      379          931        David Moyes           Marco Silva
#
#         Referee  TY  ...  Pass Completion %  Assists  Exp. Assisted Goals  \
# 0      M Oliver   2  ...               77.1        0                  0.5
# 1      M Oliver   2  ...               81.9        2                  0.5
# 2      K Friend   1  ...               58.4        0                  1.5
# 3      K Friend   1  ...               79.0        2                  1.3
# 4        M Dean   1  ...               85.2        0                  0.5
# ...         ...  ..  ...                ...      ...                  ...
# 4427  S Barrott   3  ...               74.4        1                  1.0
# 4428   S Hooper   1  ...               84.2        0                  0.5
# 4429   S Hooper   1  ...               79.7        0                  1.5
# 4430   J Brooks   1  ...               76.0        0                  0.3
# 4431  S Attwell   1  ...               82.4        0                  0.6
#
#       Expected Assists  Tackles Won  % of Dribblers Tackled  Blocks  \
# 0                  0.6           14                    40.0      13
# 1                  0.4            5                    28.6      14
# 2                  1.2           12                    47.6      16
# 3                  1.1            5                    47.1      11
# 4                  0.7           19                    42.9       5
# ...                ...          ...                     ...     ...
# 4427               1.1            8                    21.7      15
# 4428               0.9            8                    64.7      11
# 4429               1.5            6                    61.9      15
# 4430               0.1            7                    44.4      18
# 4431               0.7            8                    53.3      10
#
#      Interceptions Error  market_value_in_eur
# 0               12     1         3.064286e+07
# 1               12     1         6.357143e+07
# 2               15     0         2.196429e+06
# 3                4     0         6.035714e+06
# 4               15     1         1.060714e+07
# ...            ...   ...                  ...
# 4427            14     0         1.618750e+07
# 4428             5     1         1.813333e+07
# 4429             5     1         9.333333e+06
# 4430             8     0         3.484615e+06
# 4431             7     3         2.371333e+07
#
# [4432 rows x 40 columns]

# %%
master_df = master_df.sort_values(['club_id', 'Date'])

# %%
len(master_df)
# Out:
# 4432

# %%
# 여기까지 몸값만 추가된 것

# %%
# master_df.to_csv('non_rolling_mean.csv', index=False)

# %%
# 승률 컬럼 추가

# %%
#club_games_df = pd.read_csv('club_games.csv')

# %%
#club_games_df = club_games_df.sort_values(by=['club_id', 'game_id'])

# %%
# # 각 클럽의 총 게임 수 카운트 및 누적치로 추가
# club_games_df['total_games'] = club_games_df.groupby('club_id')['game_id'].cumcount()

# # 각 클럽의 승리한 게임 수 카운트 및 누적치로 추가
# club_games_df['wins'] = club_games_df.groupby('club_id')['is_win'].cumsum()
# club_games_df['wins'] = club_games_df.groupby('club_id')['wins'].shift(1)
# club_games_df['wins'] = club_games_df['wins'].fillna(0)

# # 승리 확률 계산 및 누적치로 추가
# club_games_df['win_percentage'] = (club_games_df['wins'] / club_games_df['total_games']) * 100
# club_games_df['win_percentage'] = club_games_df['win_percentage'].fillna(0)

# %%
# # 상대전적별 총 게임 수 카운트 및 누적치로 추가
# club_games_df['total_games_vs_opponent'] = club_games_df.groupby(['club_id', 'opponent_id'])['game_id'].cumcount()

# # 상대전적별 총 게임 수 카운트 및 누적치로 추가
# club_games_df['wins_vs_opponent'] = club_games_df.groupby(['club_id', 'opponent_id'])['is_win'].cumsum()
# club_games_df['wins_vs_opponent'] = club_games_df.groupby(['club_id', 'opponent_id'])['wins_vs_opponent'].shift(1)
# club_games_df['wins_vs_opponent'] = club_games_df['wins_vs_opponent'].fillna(0)

# # 승리 확률 계산 및 누적치로 추가
# club_games_df['win_percentage_vs_opponent'] = (club_games_df['wins_vs_opponent'] / club_games_df['total_games_vs_opponent']) * 100
# club_games_df['win_percentage_vs_opponent'] = club_games_df['win_percentage_vs_opponent'].fillna(0)

# %%
merged_df1 = merged_df1.sort_values(by=['club_id', 'date'])

# %%
# 각 클럽의 총 게임 수 카운트 및 누적치로 추가
merged_df1['total_games'] = merged_df1.groupby('club_id')['date'].cumcount()

# 각 클럽의 승리한 게임 수 카운트 및 누적치로 추가
merged_df1['wins'] = merged_df1.groupby('club_id')['is_win'].cumsum()
merged_df1['wins'] = merged_df1.groupby('club_id')['wins'].shift(1)
merged_df1['wins'] = merged_df1['wins'].fillna(0)

# 승리 확률 계산 및 누적치로 추가
merged_df1['win_percentage'] = (merged_df1['wins'] / merged_df1['total_games']) * 100
merged_df1['win_percentage'] = merged_df1['win_percentage'].fillna(0)

# %%
# 상대전적별 총 게임 수 카운트 및 누적치로 추가
merged_df1['total_games_vs_opponent'] = merged_df1.groupby(['club_id', 'opponent_id'])['date'].cumcount()

# 상대전적별 총 게임 수 카운트 및 누적치로 추가
merged_df1['wins_vs_opponent'] = merged_df1.groupby(['club_id', 'opponent_id'])['is_win'].cumsum()
merged_df1['wins_vs_opponent'] = merged_df1.groupby(['club_id', 'opponent_id'])['wins_vs_opponent'].shift(1)
merged_df1['wins_vs_opponent'] = merged_df1['wins_vs_opponent'].fillna(0)

# 승리 확률 계산 및 누적치로 추가
merged_df1['win_percentage_vs_opponent'] = (merged_df1['wins_vs_opponent'] / merged_df1['total_games_vs_opponent']) * 100
merged_df1['win_percentage_vs_opponent'] = merged_df1['win_percentage_vs_opponent'].fillna(0)

# %%
merged_df1
# Out:
#       game_id       date  club_id  own_goals  own_position  own_manager_name  \
# 933   3050167 2018-08-12       11          0          15.0        Unai Emery
# 2315  3050180 2018-08-18       11          2          17.0        Unai Emery
# 1777  3050187 2018-08-25       11          3           9.0        Unai Emery
# 2225  3050199 2018-09-02       11          3           9.0        Unai Emery
# 3159  3050212 2018-09-15       11          2           7.0        Unai Emery
# ...       ...        ...      ...        ...           ...               ...
# 535   4095353 2024-03-10     1237          1           8.0  Roberto De Zerbi
# 4256  4095374 2024-03-31     1237          1           9.0  Roberto De Zerbi
# 3154  4095382 2024-04-03     1237          0           9.0  Roberto De Zerbi
# 402   4095391 2024-04-06     1237          0          10.0  Roberto De Zerbi
# 4413  4095403 2024-04-13     1237          1          10.0  Roberto De Zerbi
#
#       opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 933           281               2                3.0         Pep Guardiola
# 2315          631               3                3.0        Maurizio Sarri
# 1777          379               1               20.0     Manuel Pellegrini
# 2225          603               2               16.0          Neil Warnock
# 3159          762               1               19.0        Rafael Benítez
# ...           ...             ...                ...                   ...
# 535           703               0               18.0   Nuno Espírito Santo
# 4256           31               2                1.0          Jürgen Klopp
# 3154         1148               0               15.0          Thomas Frank
# 402            11               3                1.0          Mikel Arteta
# 4413         1132               1               19.0       Vincent Kompany
#
#      hosting  is_win  total_games  wins  win_percentage  \
# 933     Home       0            0   0.0        0.000000
# 2315    Away       0            1   0.0        0.000000
# 1777    Home       1            2   0.0        0.000000
# 2225    Away       1            3   1.0       33.333333
# 3159    Away       1            4   2.0       50.000000
# ...      ...     ...          ...   ...             ...
# 535     Home       1          217  67.0       30.875576
# 4256    Away       0          218  68.0       31.192661
# 3154    Away       0          219  68.0       31.050228
# 402     Home       0          220  68.0       30.909091
# 4413    Away       0          221  68.0       30.769231
#
#       total_games_vs_opponent  wins_vs_opponent  win_percentage_vs_opponent
# 933                         0               0.0                    0.000000
# 2315                        0               0.0                    0.000000
# 1777                        0               0.0                    0.000000
# 2225                        0               0.0                    0.000000
# 3159                        0               0.0                    0.000000
# ...                       ...               ...                         ...
# 535                         3               1.0                   33.333333
# 4256                       11               2.0                   18.181818
# 3154                        5               3.0                   60.000000
# 402                        11               4.0                   36.363636
# 4413                        9               2.0                   22.222222
#
# [4446 rows x 18 columns]

# %%
master_df2 = pd.merge(master_df, merged_df1[['game_id', 'club_id', 'opponent_id', 'total_games', 'wins', 'win_percentage', 'total_games_vs_opponent', 'wins_vs_opponent', 'win_percentage_vs_opponent']], on=(['game_id', 'club_id', 'opponent_id']))

# %%
master_df2 = master_df2.sort_values(['club_id', 'Date'])

# %%
master_df2.isnull().sum()
# Out:
# game_id                       0
# Date                          0
# Team                          0
# Opponent                      0
# club_id                       0
# opponent_id                   0
# own_manager_name              0
# opponent_manager_name         0
# Referee                       0
# TY                            0
# OY                            0
# TR                            0
# OR                            0
# B365TW                        0
# B365D                         0
# B365OW                        0
# Table                         0
# Venue                         0
# Result                        0
# Possesion                     0
# Aerial Duels(%)               0
# GF                            0
# GA                            0
# Oppo. Table                   0
# Shot on Target                0
# Shot on Target(%)             0
# Goals per Shot                0
# Expected Goals                0
# Save%                         0
# Clean Sheet                   0
# Pass Completion %             0
# Assists                       0
# Exp. Assisted Goals           0
# Expected Assists              0
# Tackles Won                   0
# % of Dribblers Tackled        0
# Blocks                        0
# Interceptions                 0
# Error                         0
# market_value_in_eur           0
# total_games                   0
# wins                          0
# win_percentage                0
# total_games_vs_opponent       0
# wins_vs_opponent              0
# win_percentage_vs_opponent    0
# dtype: int64

# %%
master_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4432 entries, 0 to 4431
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   game_id                     4432 non-null   int64
#  1   Date                        4432 non-null   datetime64[ns]
#  2   Team                        4432 non-null   object
#  3   Opponent                    4432 non-null   object
#  4   club_id                     4432 non-null   int64
#  5   opponent_id                 4432 non-null   int64
#  6   own_manager_name            4432 non-null   object
#  7   opponent_manager_name       4432 non-null   object
#  8   Referee                     4432 non-null   object
#  9   TY                          4432 non-null   int64
#  10  OY                          4432 non-null   int64
#  11  TR                          4432 non-null   int64
#  12  OR                          4432 non-null   int64
#  13  B365TW                      4432 non-null   float64
#  14  B365D                       4432 non-null   float64
#  15  B365OW                      4432 non-null   float64
#  16  Table                       4432 non-null   int64
#  17  Venue                       4432 non-null   object
#  18  Result                      4432 non-null   object
#  19  Possesion                   4432 non-null   int64
#  20  Aerial Duels(%)             4432 non-null   float64
#  21  GF                          4432 non-null   int64
#  22  GA                          4432 non-null   float64
#  23  Oppo. Table                 4432 non-null   int64
#  24  Shot on Target              4432 non-null   int64
#  25  Shot on Target(%)           4432 non-null   float64
#  26  Goals per Shot              4432 non-null   float64
#  27  Expected Goals              4432 non-null   float64
#  28  Save%                       4432 non-null   float64
#  29  Clean Sheet                 4432 non-null   int64
#  30  Pass Completion %           4432 non-null   float64
#  31  Assists                     4432 non-null   int64
#  32  Exp. Assisted Goals         4432 non-null   float64
#  33  Expected Assists            4432 non-null   float64
#  34  Tackles Won                 4432 non-null   int64
#  35  % of Dribblers Tackled      4432 non-null   float64
#  36  Blocks                      4432 non-null   int64
#  37  Interceptions               4432 non-null   int64
#  38  Error                       4432 non-null   int64
#  39  market_value_in_eur         4432 non-null   float64
#  40  total_games                 4432 non-null   int64
#  41  wins                        4432 non-null   float64
#  42  win_percentage              4432 non-null   float64
#  43  total_games_vs_opponent     4432 non-null   int64
#  44  wins_vs_opponent            4432 non-null   float64
#  45  win_percentage_vs_opponent  4432 non-null   float64
# dtypes: datetime64[ns](1), float64(18), int64(20), object(7)
# memory usage: 1.6+ MB

# %%
master_df2
# Out:
#       game_id       Date                    Team           Opponent  club_id  \
# 0     3050167 2018-08-12                 Arsenal    Manchester City       11
# 1     3050180 2018-08-18                 Arsenal            Chelsea       11
# 2     3050187 2018-08-25                 Arsenal           West Ham       11
# 3     3050199 2018-09-02                 Arsenal       Cardiff City       11
# 4     3050212 2018-09-15                 Arsenal      Newcastle Utd       11
# ...       ...        ...                     ...                ...      ...
# 4427  4095353 2024-03-10  Brighton & Hove Albion  Nottingham Forest     1237
# 4428  4095374 2024-03-31  Brighton & Hove Albion          Liverpool     1237
# 4429  4095382 2024-04-03  Brighton & Hove Albion          Brentford     1237
# 4430  4095391 2024-04-06  Brighton & Hove Albion            Arsenal     1237
# 4431  4095403 2024-04-13  Brighton & Hove Albion            Burnley     1237
#
#       opponent_id  own_manager_name opponent_manager_name      Referee  TY  \
# 0             281        Unai Emery         Pep Guardiola     M Oliver   2
# 1             631        Unai Emery        Maurizio Sarri   M Atkinson   2
# 2             379        Unai Emery     Manuel Pellegrini      G Scott   1
# 3             603        Unai Emery          Neil Warnock     A Taylor   4
# 4             762        Unai Emery        Rafael Benítez    L Probert   0
# ...           ...               ...                   ...          ...  ..
# 4427          703  Roberto De Zerbi   Nuno Espírito Santo  M Salisbury   4
# 4428           31  Roberto De Zerbi          Jürgen Klopp      D Coote   3
# 4429         1148  Roberto De Zerbi          Thomas Frank     A Madley   1
# 4430           11  Roberto De Zerbi          Mikel Arteta     J Brooks   1
# 4431         1132  Roberto De Zerbi       Vincent Kompany     S Hooper   1
#
#       ...  Blocks  Interceptions  Error  market_value_in_eur  total_games  \
# 0     ...      13             12      1         3.064286e+07            0
# 1     ...      12             12      2         3.235714e+07            1
# 2     ...      14              6      1         3.021429e+07            2
# 3     ...       6             11      2         3.235714e+07            3
# 4     ...       7              7      0         3.235714e+07            4
# ...   ...     ...            ...    ...                  ...          ...
# 4427  ...       9              5      1         1.906250e+07          217
# 4428  ...      18              9      0         1.766667e+07          218
# 4429  ...       9              8      0         1.606667e+07          219
# 4430  ...      17             10      0         1.985714e+07          220
# 4431  ...      11              5      1         1.813333e+07          221
#
#       wins  win_percentage total_games_vs_opponent wins_vs_opponent  \
# 0      0.0        0.000000                       0              0.0
# 1      0.0        0.000000                       0              0.0
# 2      0.0        0.000000                       0              0.0
# 3      1.0       33.333333                       0              0.0
# 4      2.0       50.000000                       0              0.0
# ...    ...             ...                     ...              ...
# 4427  67.0       30.875576                       3              1.0
# 4428  68.0       31.192661                      11              2.0
# 4429  68.0       31.050228                       5              3.0
# 4430  68.0       30.909091                      11              4.0
# 4431  68.0       30.769231                       9              2.0
#
#       win_percentage_vs_opponent
# 0                       0.000000
# 1                       0.000000
# 2                       0.000000
# 3                       0.000000
# 4                       0.000000
# ...                          ...
# 4427                   33.333333
# 4428                   18.181818
# 4429                   60.000000
# 4430                   36.363636
# 4431                   22.222222
#
# [4432 rows x 46 columns]

# %%
master_df2.to_csv('master_df(train+validation).csv', index = False)
