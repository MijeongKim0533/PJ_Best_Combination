# %% [markdown]
# 1. null, 이상치 제거 (z-score 그래프 보고 3, 4, 5, 6, 7) 다양한 시도 해봐야 함
# 2. 스케일링 standard, minmax, robust, maxabs + log 스케일링 다 시도해 보아야 함
# 3. 모델은 여러개 쓰지 않더라도 랜덤, xgboost, lightGBM, gradiant 시도해 보고 -> 스태킹 앙상블 사용해보기
# 4. 하이퍼 파라미터 조정하기
# 5. 생각나면 추가적으로

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
import xgboost as xgb
from sklearn.feature_selection import RFECV

# %%
df = pd.read_csv('./game_result/merged_FBREF.csv')

# %%
df.head()
# Out:
#          Date                    Team        Opponent     Referee  TY  OY  TR  \
# 0  2018-08-10          Leicester City  Manchester Utd  A Marriner   1   2   0
# 1  2018-08-10          Manchester Utd  Leicester City  A Marriner   2   1   0
# 2  2018-08-11             Bournemouth    Cardiff City    K Friend   1   1   0
# 3  2018-08-11  Brighton & Hove Albion         Watford      J Moss   2   2   0
# 4  2018-08-11            Cardiff City     Bournemouth    K Friend   1   1   0
#
#    OR  B365TW  B365D  ...  Clean Sheet  Pass Completion % Assists  \
# 0   0    7.50    3.9  ...            0               79.4       0
# 1   0    1.57    3.9  ...            0               80.1       1
# 2   0    1.90    3.6  ...            1               79.0       2
# 3   0    3.40    3.2  ...            0               74.4       0
# 4   0    4.50    3.6  ...            0               58.4       0
#
#   Exp. Assisted Goals  Expected Assists  Tackles Won % of Dribblers Tackled  \
# 0                 0.8               1.0           11                   21.4
# 1                 0.7               0.3           13                   50.0
# 2                 1.3               1.1            5                   47.1
# 3                 0.3               0.2           11                   50.0
# 4                 1.5               1.2           12                   47.6
#
#   Blocks Interceptions  Error
# 0      8            12      0
# 1     15            17      0
# 2     11             4      0
# 3     14            17      0
# 4     16            15      0
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Team', 'Opponent', 'Referee', 'TY', 'OY', 'TR', 'OR', 'B365TW',
#        'B365D', 'B365OW', 'Season', 'Time', 'Round', 'Round.1', 'Table', 'Day',
#        'Venue', 'Result', 'Possesion', 'Aerial Duels(%)', 'GF', 'GA',
#        'Oppo. Table', 'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
#        'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
#        'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
#        '% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                      0
# Team                      0
# Opponent                  0
# Referee                   0
# TY                        0
# OY                        0
# TR                        0
# OR                        0
# B365TW                    0
# B365D                     0
# B365OW                    0
# Season                    0
# Time                      0
# Round                     0
# Round.1                   0
# Table                     0
# Day                       0
# Venue                     0
# Result                    0
# Possesion                 0
# Aerial Duels(%)           0
# GF                        0
# GA                        0
# Oppo. Table               0
# Shot on Target            0
# Shot on Target(%)         2
# Goals per Shot            2
# Expected Goals            0
# Save%                     0
# Clean Sheet               0
# Pass Completion %         0
# Assists                   0
# Exp. Assisted Goals       0
# Expected Assists          0
# Tackles Won               0
# % of Dribblers Tackled    0
# Blocks                    0
# Interceptions             0
# Error                     0
# dtype: int64

# %%
# 위의 null은 슈팅 자체가 0개여서 생김 -> 그러므로 0으로 대체함

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Date                      0
# Team                      0
# Opponent                  0
# Referee                   0
# TY                        0
# OY                        0
# TR                        0
# OR                        0
# B365TW                    0
# B365D                     0
# B365OW                    0
# Season                    0
# Time                      0
# Round                     0
# Round.1                   0
# Table                     0
# Day                       0
# Venue                     0
# Result                    0
# Possesion                 0
# Aerial Duels(%)           0
# GF                        0
# GA                        0
# Oppo. Table               0
# Shot on Target            0
# Shot on Target(%)         0
# Goals per Shot            0
# Expected Goals            0
# Save%                     0
# Clean Sheet               0
# Pass Completion %         0
# Assists                   0
# Exp. Assisted Goals       0
# Expected Assists          0
# Tackles Won               0
# % of Dribblers Tackled    0
# Blocks                    0
# Interceptions             0
# Error                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Team', 'Opponent', 'Referee', 'TY', 'OY', 'TR', 'OR', 'B365TW',
#        'B365D', 'B365OW', 'Season', 'Time', 'Round', 'Round.1', 'Table', 'Day',
#        'Venue', 'Result', 'Possesion', 'Aerial Duels(%)', 'GF', 'GA',
#        'Oppo. Table', 'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
#        'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
#        'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
#        '% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error'],
#       dtype='object')

# %%
# 지금 이 데이터셋에는 감독이 없는데 club_games 데이터셋의 감독을 넣어서 모델링
# -> club_games, games dataset 가져와야 함

# %%
club_games_df = pd.read_csv('./data/club_games.csv')

# %%
club_games_df
# Out:
#         game_id  club_id  own_goals  own_position        own_manager_name  \
# 0       2320450     1468          0           NaN       Holger Bachthaler
# 1       2320460        1          3           NaN         Jürgen Luginger
# 2       2320472     2036          4           NaN           Frank Schmidt
# 3       2321044       16          2           1.0            Jürgen Klopp
# 4       2321060       23          0          18.0    Torsten Lieberknecht
# ...         ...      ...        ...           ...                     ...
# 134837  3142950      681          0           NaN         Imanol Alguacil
# 134838  3148382      150          1           NaN           Quique Setién
# 134839  3153158      418          1           NaN         Santiago Solari
# 134840  3307741    36661          1           NaN      Aleksandr Gorshkov
# 134841  3520159    50600          0           NaN  Aleksandr Kishinevskiy
#
#         opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 0                24               2                NaN             Armin Veh
# 1                86               1                NaN            Robin Dutt
# 2                72               5                NaN     Alexander Schmidt
# 3                23               1               15.0  Torsten Lieberknecht
# 4                24               2               11.0             Armin Veh
# ...             ...             ...                ...                   ...
# 134837          150               0                NaN         Quique Setién
# 134838          714               1                NaN                  Rubi
# 134839          131               1                NaN      Ernesto Valverde
# 134840        32218               2                NaN    Viktor Antikhovich
# 134841        12060               4                NaN     Evgeniy Kharlanov
#
#        hosting  is_win
# 0         Home       0
# 1         Home       1
# 2         Home       0
# 3         Home       1
# 4         Home       0
# ...        ...     ...
# 134837    Away       0
# 134838    Away       0
# 134839    Away       0
# 134840    Away       0
# 134841    Away       0
#
# [134842 rows x 11 columns]

# %%
club_games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134842 entries, 0 to 134841
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   game_id                134842 non-null  int64
#  1   club_id                134842 non-null  int64
#  2   own_goals              134842 non-null  int64
#  3   own_position           94898 non-null   float64
#  4   own_manager_name       133350 non-null  object
#  5   opponent_id            134842 non-null  int64
#  6   opponent_goals         134842 non-null  int64
#  7   opponent_position      94898 non-null   float64
#  8   opponent_manager_name  133350 non-null  object
#  9   hosting                134842 non-null  object
#  10  is_win                 134842 non-null  int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 11.3+ MB

# %%
games_df = pd.read_csv('./data/games.csv')

# %%
games_df
# Out:
#        game_id competition_id  season                     round        date  \
# 0      2321044             L1    2013               2. Matchday  2013-08-18
# 1      2321060             L1    2013               3. Matchday  2013-08-25
# 2      2321086             L1    2013               6. Matchday  2013-09-21
# 3      2321152             L1    2013              11. Matchday  2013-11-02
# 4      2321205             L1    2013              17. Matchday  2013-12-21
# ...        ...            ...     ...                       ...         ...
# 67416  2629035            NLP    2015               Third Round  2015-10-27
# 67417  3092951            CLQ    2018  Qualifying Round 2nd leg  2018-08-29
# 67418  4164101            CGB    2023              Second Round  2023-08-29
# 67419  3143618            FAC    2018        Third Round Replay  2019-01-15
# 67420  4233201            SFA    2023              Fourth Round  2024-01-20
#
#        home_club_id  away_club_id  home_club_goals  away_club_goals  \
# 0                16            23                2                1
# 1                23            24                0                2
# 2                 4            16                1                1
# 3                44            33                0                2
# 4                41            39                2                3
# ...             ...           ...              ...              ...
# 67416           383         16866                6                0
# 67417           383           713                3                0
# 67418           512          1194                6                1
# 67419           512          3054                2                3
# 67420           987          3020                3                1
#
#        home_club_position  ...                stadium attendance  \
# 0                     1.0  ...      SIGNAL IDUNA PARK    80200.0
# 1                    18.0  ...      EINTRACHT-Stadion    23325.0
# 2                    15.0  ...    Max-Morlock-Stadion    50000.0
# 3                     7.0  ...  Olympiastadion Berlin    69277.0
# 4                    14.0  ...       Volksparkstadion    50000.0
# ...                   ...  ...                    ...        ...
# 67416                 NaN  ...        Philips Stadion    31000.0
# 67417                 NaN  ...        Philips Stadion    34200.0
# 67418                 NaN  ...         bet365 Stadium     9410.0
# 67419                 NaN  ...         bet365 Stadium    10261.0
# 67420                 NaN  ...               Fir Park     4119.0
#
#                  referee                                                url  \
# 0           Peter Sippel  https://www.transfermarkt.co.uk/borussia-dortm...
# 1         Wolfgang Stark  https://www.transfermarkt.co.uk/eintracht-brau...
# 2           Knut Kircher  https://www.transfermarkt.co.uk/1-fc-nuremberg...
# 3            Günter Perl  https://www.transfermarkt.co.uk/hertha-bsc_fc-...
# 4        Bastian Dankert  https://www.transfermarkt.co.uk/hamburger-sv_1...
# ...                  ...                                                ...
# 67416    Allard Lindhout  https://www.transfermarkt.co.uk/spielbericht/i...
# 67417     Anthony Taylor  https://www.transfermarkt.co.uk/spielbericht/i...
# 67418  Michael Salisbury  https://www.transfermarkt.co.uk/spielbericht/i...
# 67419   Geoff Eltringham  https://www.transfermarkt.co.uk/spielbericht/i...
# 67420        John Beaton  https://www.transfermarkt.co.uk/spielbericht/i...
#
#              home_club_formation        away_club_formation  \
# 0                        4-2-3-1                    4-3-2-1
# 1                        4-3-2-1                    4-2-3-1
# 2                        4-2-3-1                    4-2-3-1
# 3                        4-2-3-1                    4-2-3-1
# 4                        4-2-3-1              4-4-2 Diamond
# ...                          ...                        ...
# 67416            4-3-3 Attacking                      4-4-2
# 67417            4-3-3 Defending                      4-5-1
# 67418  Starting Line-up: 4-2-3-1  Starting Line-up: 4-2-3-1
# 67419              4-4-2 Diamond                    4-2-3-1
# 67420                        NaN  Starting Line-up: 4-2-3-1
#
#                                           home_club_name  \
# 0                                      Borussia Dortmund
# 1                                 Eintracht Braunschweig
# 2                                         1.FC Nuremberg
# 3                                             Hertha BSC
# 4                                           Hamburger SV
# ...                                                  ...
# 67416  Eindhovense Voetbalvereniging Philips Sport Ve...
# 67417  Eindhovense Voetbalvereniging Philips Sport Ve...
# 67418                                         Stoke City
# 67419                                         Stoke City
# 67420                           Motherwell Football Club
#
#                              away_club_name aggregate   competition_type
# 0                    Eintracht Braunschweig       2:1    domestic_league
# 1            Eintracht Frankfurt Fußball AG       0:2    domestic_league
# 2                         Borussia Dortmund       1:1    domestic_league
# 3                             FC Schalke 04       0:2    domestic_league
# 4      1. Fußball- und Sportverein Mainz 05       2:3    domestic_league
# ...                                     ...       ...                ...
# 67416                                   NaN       6:0       domestic_cup
# 67417                                   NaN       3:0  international_cup
# 67418                                   NaN       6:1              other
# 67419                                   NaN       2:3       domestic_cup
# 67420                                   NaN       3:1       domestic_cup
#
# [67421 rows x 23 columns]

# %%
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67421 entries, 0 to 67420
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 67421 non-null  int64
#  1   competition_id          67421 non-null  object
#  2   season                  67421 non-null  int64
#  3   round                   67421 non-null  object
#  4   date                    67421 non-null  object
#  5   home_club_id            67421 non-null  int64
#  6   away_club_id            67421 non-null  int64
#  7   home_club_goals         67421 non-null  int64
#  8   away_club_goals         67421 non-null  int64
#  9   home_club_position      47449 non-null  float64
#  10  away_club_position      47449 non-null  float64
#  11  home_club_manager_name  66675 non-null  object
#  12  away_club_manager_name  66675 non-null  object
#  13  stadium                 67207 non-null  object
#  14  attendance              57718 non-null  float64
#  15  referee                 66823 non-null  object
#  16  url                     67421 non-null  object
#  17  home_club_formation     60823 non-null  object
#  18  away_club_formation     60969 non-null  object
#  19  home_club_name          55971 non-null  object
#  20  away_club_name          57209 non-null  object
#  21  aggregate               67421 non-null  object
#  22  competition_type        67421 non-null  object
# dtypes: float64(3), int64(6), object(14)
# memory usage: 11.8+ MB

# %%
games_df = games_df[games_df['competition_id'] == 'GB1']

# %%
games_df
# Out:
#        game_id competition_id  season         round        date  home_club_id  \
# 24     2332021            GB1    2013  17. Matchday  2013-12-21           984
# 25     2332050            GB1    2013  14. Matchday  2013-12-04           289
# 26     2332053            GB1    2013  13. Matchday  2013-11-30           379
# 27     2332188            GB1    2013  23. Matchday  2014-01-28           180
# 28     2332235            GB1    2013  23. Matchday  2014-01-28           873
# ...        ...            ...     ...           ...         ...           ...
# 67061  2258968            GB1    2012  21. Matchday  2013-01-01           281
# 67152  3429694            GB1    2020  21. Matchday  2021-01-31          1237
# 67160  3592240            GB1    2021  37. Matchday  2022-05-15           148
# 67291  2872297            GB1    2017  19. Matchday  2017-12-23          1132
# 67316  2486614            GB1    2014  15. Matchday  2014-12-06          1039
#
#        away_club_id  home_club_goals  away_club_goals  home_club_position  \
# 24             3008                1                1                16.0
# 25              631                3                4                20.0
# 26              931                3                0                15.0
# 27               11                2                2                 9.0
# 28             3008                1                0                14.0
# ...             ...              ...              ...                 ...
# 67061           512                3                0                 2.0
# 67152           148                1                0                17.0
# 67160          1132                1                0                 4.0
# 67291           148                0                3                 7.0
# 67316          1132                2                0                17.0
#
#        ...                    stadium attendance          referee  \
# 24     ...              The Hawthorns    24753.0    Jonathan Moss
# 25     ...           Stadium of Light    40652.0        Phil Dowd
# 26     ...              Boleyn Ground    34946.0  Martin Atkinson
# 27     ...          St Mary's Stadium    31284.0        Lee Mason
# 28     ...              Selhurst Park    22519.0       Roger East
# ...    ...                        ...        ...              ...
# 67061  ...             Etihad Stadium    47192.0   Michael Oliver
# 67152  ...               AMEX Stadium        NaN     Peter Bankes
# 67160  ...  Tottenham Hotspur Stadium    61729.0     Kevin Friend
# 67291  ...                  Turf Moor    21650.0   Michael Oliver
# 67316  ...        Loftus Road Stadium    17785.0    Jonathan Moss
#
#                                                      url  home_club_formation  \
# 24     https://www.transfermarkt.co.uk/west-bromwich-...              4-2-3-1
# 25     https://www.transfermarkt.co.uk/sunderland-afc...              4-1-4-1
# 26     https://www.transfermarkt.co.uk/west-ham-unite...              4-2-3-1
# 27     https://www.transfermarkt.co.uk/southampton-fc...              4-2-3-1
# 28     https://www.transfermarkt.co.uk/crystal-palace...       4-4-2 double 6
# ...                                                  ...                  ...
# 67061  https://www.transfermarkt.co.uk/manchester-cit...                  NaN
# 67152  https://www.transfermarkt.co.uk/brighton-amp-h...              3-4-2-1
# 67160  https://www.transfermarkt.co.uk/tottenham-hots...                5-4-1
# 67291  https://www.transfermarkt.co.uk/burnley-fc_tot...              4-2-3-1
# 67316  https://www.transfermarkt.co.uk/queens-park-ra...       4-4-2 double 6
#
#       away_club_formation                          home_club_name  \
# 24                  5-3-2                    West Bromwich Albion
# 25                4-2-3-1                          Sunderland AFC
# 26                4-4-1-1           West Ham United Football Club
# 27                4-2-3-1                          Southampton FC
# 28             3-5-2 flat            Crystal Palace Football Club
# ...                   ...                                     ...
# 67061                 NaN           Manchester City Football Club
# 67152             3-4-2-1  Brighton and Hove Albion Football Club
# 67160               5-3-2         Tottenham Hotspur Football Club
# 67291             4-2-3-1                   Burnley Football Club
# 67316             4-4-1-1                     Queens Park Rangers
#
#                         away_club_name aggregate competition_type
# 24                           Hull City       1:1  domestic_league
# 25               Chelsea Football Club       3:4  domestic_league
# 26                Fulham Football Club       3:0  domestic_league
# 27               Arsenal Football Club       2:2  domestic_league
# 28                           Hull City       1:0  domestic_league
# ...                                ...       ...              ...
# 67061                       Stoke City       3:0  domestic_league
# 67152  Tottenham Hotspur Football Club       1:0  domestic_league
# 67160            Burnley Football Club       1:0  domestic_league
# 67291  Tottenham Hotspur Football Club       0:3  domestic_league
# 67316            Burnley Football Club       2:0  domestic_league
#
# [4463 rows x 23 columns]

# %%
games_df['date'] = pd.to_datetime(games_df['date'])

# %%
games_df = games_df[games_df['date'] >= '2018-08-01']

# %%
games_df
# Out:
#        game_id competition_id  season         round       date  home_club_id  \
# 1876   3050170            GB1    2018   1. Matchday 2018-08-11          1110
# 1877   3050215            GB1    2018   5. Matchday 2018-09-15          1010
# 1878   3050250            GB1    2018   9. Matchday 2018-10-20           631
# 1879   3050264            GB1    2018  10. Matchday 2018-10-27           180
# 1880   3050336            GB1    2018  17. Matchday 2018-12-15           543
# ...        ...            ...     ...           ...        ...           ...
# 66901  3050278            GB1    2018  12. Matchday 2018-11-10           603
# 66913  3421741            GB1    2020   7. Matchday 2020-11-01           148
# 66914  3429714            GB1    2020  23. Matchday 2021-02-06          1132
# 67152  3429694            GB1    2020  21. Matchday 2021-01-31          1237
# 67160  3592240            GB1    2021  37. Matchday 2022-05-15           148
#
#        away_club_id  home_club_goals  away_club_goals  home_club_position  \
# 1876            631                0                3                19.0
# 1877            985                1                2                 4.0
# 1878            985                2                2                 3.0
# 1879            762                0                0                16.0
# 1880            989                2                0                 7.0
# ...             ...              ...              ...                 ...
# 66901          1237                2                1                18.0
# 66913          1237                2                1                 3.0
# 66914          1237                1                1                17.0
# 67152           148                1                0                17.0
# 67160          1132                1                0                 4.0
#
#        ...                    stadium attendance          referee  \
# 1876   ...       John Smith's Stadium    24121.0   Chris Kavanagh
# 1877   ...              Vicarage Road    20537.0        Mike Dean
# 1878   ...            Stamford Bridge    40721.0        Mike Dean
# 1879   ...          St Mary's Stadium    30736.0   Chris Kavanagh
# 1880   ...           Molineux Stadium    30997.0     Simon Hooper
# ...    ...                        ...        ...              ...
# 66901  ...       Cardiff City Stadium    29402.0  Martin Atkinson
# 66913  ...  Tottenham Hotspur Stadium        NaN     Graham Scott
# 66914  ...                  Turf Moor        NaN   Anthony Taylor
# 67152  ...               AMEX Stadium        NaN     Peter Bankes
# 67160  ...  Tottenham Hotspur Stadium    61729.0     Kevin Friend
#
#                                                      url  home_club_formation  \
# 1876   https://www.transfermarkt.co.uk/huddersfield-t...           3-5-2 flat
# 1877   https://www.transfermarkt.co.uk/watford-fc_man...                4-4-2
# 1878   https://www.transfermarkt.co.uk/chelsea-fc_man...      4-3-3 Attacking
# 1879   https://www.transfermarkt.co.uk/southampton-fc...       4-4-2 double 6
# 1880   https://www.transfermarkt.co.uk/wolverhampton-...                3-5-2
# ...                                                  ...                  ...
# 66901  https://www.transfermarkt.co.uk/cardiff-city_b...      4-3-3 Attacking
# 66913  https://www.transfermarkt.co.uk/tottenham-hots...              4-2-3-1
# 66914  https://www.transfermarkt.co.uk/burnley-fc_bri...       4-4-2 double 6
# 67152  https://www.transfermarkt.co.uk/brighton-amp-h...              3-4-2-1
# 67160  https://www.transfermarkt.co.uk/tottenham-hots...                5-4-1
#
#       away_club_formation                          home_club_name  \
# 1876      4-3-3 Attacking                       Huddersfield Town
# 1877              4-2-3-1                              Watford FC
# 1878      4-3-3 Attacking                   Chelsea Football Club
# 1879       4-4-2 double 6                          Southampton FC
# 1880              3-4-2-1   Wolverhampton Wanderers Football Club
# ...                   ...                                     ...
# 66901             4-2-3-1                            Cardiff City
# 66913          3-5-2 flat         Tottenham Hotspur Football Club
# 66914               5-3-2                   Burnley Football Club
# 67152             3-4-2-1  Brighton and Hove Albion Football Club
# 67160               5-3-2         Tottenham Hotspur Football Club
#
#                                away_club_name aggregate competition_type
# 1876                    Chelsea Football Club       0:3  domestic_league
# 1877          Manchester United Football Club       1:2  domestic_league
# 1878          Manchester United Football Club       2:2  domestic_league
# 1879           Newcastle United Football Club       0:0  domestic_league
# 1880    Association Football Club Bournemouth       2:0  domestic_league
# ...                                       ...       ...              ...
# 66901  Brighton and Hove Albion Football Club       2:1  domestic_league
# 66913  Brighton and Hove Albion Football Club       2:1  domestic_league
# 66914  Brighton and Hove Albion Football Club       1:1  domestic_league
# 67152         Tottenham Hotspur Football Club       1:0  domestic_league
# 67160                   Burnley Football Club       1:0  domestic_league
#
# [2183 rows x 23 columns]

# %%
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2183 entries, 1876 to 67160
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 2183 non-null   int64
#  1   competition_id          2183 non-null   object
#  2   season                  2183 non-null   int64
#  3   round                   2183 non-null   object
#  4   date                    2183 non-null   datetime64[ns]
#  5   home_club_id            2183 non-null   int64
#  6   away_club_id            2183 non-null   int64
#  7   home_club_goals         2183 non-null   int64
#  8   away_club_goals         2183 non-null   int64
#  9   home_club_position      2183 non-null   float64
#  10  away_club_position      2183 non-null   float64
#  11  home_club_manager_name  2183 non-null   object
#  12  away_club_manager_name  2183 non-null   object
#  13  stadium                 2183 non-null   object
#  14  attendance              1728 non-null   float64
#  15  referee                 2183 non-null   object
#  16  url                     2183 non-null   object
#  17  home_club_formation     2183 non-null   object
#  18  away_club_formation     2183 non-null   object
#  19  home_club_name          2183 non-null   object
#  20  away_club_name          2183 non-null   object
#  21  aggregate               2183 non-null   object
#  22  competition_type        2183 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(6), object(13)
# memory usage: 409.3+ KB

# %%
games_df.isnull().sum()
# Out:
# game_id                     0
# competition_id              0
# season                      0
# round                       0
# date                        0
# home_club_id                0
# away_club_id                0
# home_club_goals             0
# away_club_goals             0
# home_club_position          0
# away_club_position          0
# home_club_manager_name      0
# away_club_manager_name      0
# stadium                     0
# attendance                455
# referee                     0
# url                         0
# home_club_formation         0
# away_club_formation         0
# home_club_name              0
# away_club_name              0
# aggregate                   0
# competition_type            0
# dtype: int64

# %%
club_games_df = club_games_df[club_games_df['game_id'].isin(games_df['game_id'])]

# %%
club_games_df
# Out:
#         game_id  club_id  own_goals  own_position own_manager_name  \
# 2097    3050170     1110          0          19.0     David Wagner
# 2098    3050190     1110          0          19.0     David Wagner
# 2099    3050199      603          2          16.0     Neil Warnock
# 2100    3050215     1010          1           4.0      Javi Gracia
# 2101    3050250      631          2           3.0   Maurizio Sarri
# ...         ...      ...        ...           ...              ...
# 134815  3429732      350          0          20.0     Chris Wilder
# 134816  3429776      399          2          11.0   Marcelo Bielsa
# 134818  3592178       31          2           2.0     Jürgen Klopp
# 134821  4095319     1148          2          14.0     Thomas Frank
# 134822  3219126     1010          1          17.0    Nigel Pearson
#
#         opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 2097            631               3                2.0        Maurizio Sarri
# 2098            603               0               15.0          Neil Warnock
# 2099             11               3                9.0            Unai Emery
# 2100            985               2                8.0         José Mourinho
# 2101            985               2               10.0         José Mourinho
# ...             ...             ...                ...                   ...
# 134815          379               3                5.0           David Moyes
# 134816          931               1               18.0          Scott Parker
# 134818          405               1               15.0        Steven Gerrard
# 134821          543               0               11.0           Gary O'Neil
# 134822          379               3               15.0           David Moyes
#
#        hosting  is_win
# 2097      Home       0
# 2098      Home       0
# 2099      Home       0
# 2100      Home       0
# 2101      Home       0
# ...        ...     ...
# 134815    Away       0
# 134816    Away       1
# 134818    Away       1
# 134821    Away       1
# 134822    Away       0
#
# [4366 rows x 11 columns]

# %%
merged_df1 = pd.merge(games_df[['game_id', 'date']], club_games_df, on='game_id', how='right')

# %%
merged_df1.sort_values('game_id')
# Out:
#       game_id       date  club_id  own_goals  own_position  \
# 917   3050167 2018-08-12       11          0          15.0
# 3100  3050167 2018-08-12      281          2           3.0
# 4192  3050168 2018-08-11      603          0          17.0
# 2009  3050168 2018-08-11      989          2           5.0
# 918   3050169 2018-08-11      931          0          18.0
# ...       ...        ...      ...        ...           ...
# 1156  4095365 2024-03-16      931          3          12.0
# 225   4095366 2024-03-16     1031          1          17.0
# 2408  4095366 2024-03-16      703          1          18.0
# 4187  4095368 2024-03-17      405          1           4.0
# 2004  4095368 2024-03-17      379          1           7.0
#
#          own_manager_name  opponent_id  opponent_goals  opponent_position  \
# 917            Unai Emery          281               2                3.0
# 3100        Pep Guardiola           11               0               15.0
# 4192         Neil Warnock          989               2                5.0
# 2009           Eddie Howe          603               0               17.0
# 918     Slavisa Jokanovic          873               2                4.0
# ...                   ...          ...             ...                ...
# 1156          Marco Silva          148               0                5.0
# 225           Rob Edwards          703               1               18.0
# 2408  Nuno Espírito Santo         1031               1               17.0
# 4187           Unai Emery          379               1                7.0
# 2004          David Moyes          405               1                4.0
#
#      opponent_manager_name hosting  is_win
# 917          Pep Guardiola    Home       0
# 3100            Unai Emery    Away       1
# 4192            Eddie Howe    Away       0
# 2009          Neil Warnock    Home       1
# 918            Roy Hodgson    Home       0
# ...                    ...     ...     ...
# 1156      Ange Postecoglou    Home       1
# 225    Nuno Espírito Santo    Home       0
# 2408           Rob Edwards    Away       0
# 4187           David Moyes    Away       0
# 2004            Unai Emery    Home       0
#
# [4366 rows x 12 columns]

# %%
merged_home_df = merged_df1[merged_df1['hosting'] == 'Home']

# %%
merged_away_df = merged_df1[merged_df1['hosting'] == 'Away']

# %%
home_game_df = pd.merge(merged_home_df, games_df[['game_id', 'home_club_name']], on='game_id')

# %%
home_game_df.sort_values('game_id')
# Out:
#       game_id       date  club_id  own_goals  own_position   own_manager_name  \
# 917   3050167 2018-08-12       11          0          15.0         Unai Emery
# 2009  3050168 2018-08-11      989          2           5.0         Eddie Howe
# 918   3050169 2018-08-11      931          0          18.0  Slavisa Jokanovic
# 0     3050170 2018-08-11     1110          0          19.0       David Wagner
# 1323  3050171 2018-08-12       31          4           1.0       Jürgen Klopp
# ...       ...        ...      ...        ...           ...                ...
# 263   4095359 2024-03-09      543          2           9.0        Gary O'Neil
# 1604  4095362 2024-03-16     1132          2          19.0    Vincent Kompany
# 1156  4095365 2024-03-16      931          3          12.0        Marco Silva
# 225   4095366 2024-03-16     1031          1          17.0        Rob Edwards
# 2004  4095368 2024-03-17      379          1           7.0        David Moyes
#
#       opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 917           281               2                3.0         Pep Guardiola
# 2009          603               0               17.0          Neil Warnock
# 918           873               2                4.0           Roy Hodgson
# 0             631               3                2.0        Maurizio Sarri
# 1323          379               0               20.0     Manuel Pellegrini
# ...           ...             ...                ...                   ...
# 263           931               1               12.0           Marco Silva
# 1604         1148               1               15.0          Thomas Frank
# 1156          148               0                5.0      Ange Postecoglou
# 225           703               1               18.0   Nuno Espírito Santo
# 2004          405               1                4.0            Unai Emery
#
#      hosting  is_win                         home_club_name
# 917     Home       0                  Arsenal Football Club
# 2009    Home       1  Association Football Club Bournemouth
# 918     Home       0                   Fulham Football Club
# 0       Home       0                      Huddersfield Town
# 1323    Home       1                Liverpool Football Club
# ...      ...     ...                                    ...
# 263     Home       1  Wolverhampton Wanderers Football Club
# 1604    Home       1                  Burnley Football Club
# 1156    Home       1                   Fulham Football Club
# 225     Home       0               Luton Town Football Club
# 2004    Home       0          West Ham United Football Club
#
# [2183 rows x 13 columns]

# %%
new_column_names = {'home_club_name': 'club_name'}
home_game_df = home_game_df.rename(columns=new_column_names)

# %%
away_game_df = pd.merge(merged_away_df, games_df[['game_id', 'away_club_name']], on='game_id')

# %%
away_game_df.sort_values('game_id')
# Out:
#       game_id       date  club_id  own_goals  own_position  \
# 917   3050167 2018-08-12      281          2           3.0
# 2009  3050168 2018-08-11      603          0          17.0
# 918   3050169 2018-08-11      873          2           4.0
# 0     3050170 2018-08-11      631          3           2.0
# 1323  3050171 2018-08-12      379          0          20.0
# ...       ...        ...      ...        ...           ...
# 263   4095359 2024-03-09      931          1          12.0
# 1604  4095362 2024-03-16     1148          1          15.0
# 1156  4095365 2024-03-16      148          0           5.0
# 225   4095366 2024-03-16      703          1          18.0
# 2004  4095368 2024-03-17      405          1           4.0
#
#          own_manager_name  opponent_id  opponent_goals  opponent_position  \
# 917         Pep Guardiola           11               0               15.0
# 2009         Neil Warnock          989               2                5.0
# 918           Roy Hodgson          931               0               18.0
# 0          Maurizio Sarri         1110               0               19.0
# 1323    Manuel Pellegrini           31               4                1.0
# ...                   ...          ...             ...                ...
# 263           Marco Silva          543               2                9.0
# 1604         Thomas Frank         1132               2               19.0
# 1156     Ange Postecoglou          931               3               12.0
# 225   Nuno Espírito Santo         1031               1               17.0
# 2004           Unai Emery          379               1                7.0
#
#      opponent_manager_name hosting  is_win                   away_club_name
# 917             Unai Emery    Away       1    Manchester City Football Club
# 2009            Eddie Howe    Away       0                     Cardiff City
# 918      Slavisa Jokanovic    Away       1     Crystal Palace Football Club
# 0             David Wagner    Away       1            Chelsea Football Club
# 1323          Jürgen Klopp    Away       0    West Ham United Football Club
# ...                    ...     ...     ...                              ...
# 263            Gary O'Neil    Away       0             Fulham Football Club
# 1604       Vincent Kompany    Away       0          Brentford Football Club
# 1156           Marco Silva    Away       0  Tottenham Hotspur Football Club
# 225            Rob Edwards    Away       0  Nottingham Forest Football Club
# 2004           David Moyes    Away       0        Aston Villa Football Club
#
# [2183 rows x 13 columns]

# %%
new_column_names = {'away_club_name': 'club_name'}
away_game_df = away_game_df.rename(columns=new_column_names)

# %%
m_merged_df = pd.concat([home_game_df, away_game_df], axis=0).sort_values('game_id')

# %%
# 이 df가 games, club_games 합친 df
m_merged_df
# Out:
#       game_id       date  club_id  own_goals  own_position  \
# 917   3050167 2018-08-12       11          0          15.0
# 917   3050167 2018-08-12      281          2           3.0
# 2009  3050168 2018-08-11      603          0          17.0
# 2009  3050168 2018-08-11      989          2           5.0
# 918   3050169 2018-08-11      931          0          18.0
# ...       ...        ...      ...        ...           ...
# 1156  4095365 2024-03-16      931          3          12.0
# 225   4095366 2024-03-16     1031          1          17.0
# 225   4095366 2024-03-16      703          1          18.0
# 2004  4095368 2024-03-17      405          1           4.0
# 2004  4095368 2024-03-17      379          1           7.0
#
#          own_manager_name  opponent_id  opponent_goals  opponent_position  \
# 917            Unai Emery          281               2                3.0
# 917         Pep Guardiola           11               0               15.0
# 2009         Neil Warnock          989               2                5.0
# 2009           Eddie Howe          603               0               17.0
# 918     Slavisa Jokanovic          873               2                4.0
# ...                   ...          ...             ...                ...
# 1156          Marco Silva          148               0                5.0
# 225           Rob Edwards          703               1               18.0
# 225   Nuno Espírito Santo         1031               1               17.0
# 2004           Unai Emery          379               1                7.0
# 2004          David Moyes          405               1                4.0
#
#      opponent_manager_name hosting  is_win  \
# 917          Pep Guardiola    Home       0
# 917             Unai Emery    Away       1
# 2009            Eddie Howe    Away       0
# 2009          Neil Warnock    Home       1
# 918            Roy Hodgson    Home       0
# ...                    ...     ...     ...
# 1156      Ange Postecoglou    Home       1
# 225    Nuno Espírito Santo    Home       0
# 225            Rob Edwards    Away       0
# 2004           David Moyes    Away       0
# 2004            Unai Emery    Home       0
#
#                                   club_name
# 917                   Arsenal Football Club
# 917           Manchester City Football Club
# 2009                           Cardiff City
# 2009  Association Football Club Bournemouth
# 918                    Fulham Football Club
# ...                                     ...
# 1156                   Fulham Football Club
# 225                Luton Town Football Club
# 225         Nottingham Forest Football Club
# 2004              Aston Villa Football Club
# 2004          West Ham United Football Club
#
# [4366 rows x 13 columns]

# %%
# 'Referee'를 drop시킨 이유는 경기일 이전에 알기 힘든 정보라서 제외 -> 이번에는 넣었음

# %%
dropped_df = df.drop(['Season', 'Time', 'Round', 'Round.1', 'Day'], axis=1)

# %%
dropped_df.columns
# Out:
# Index(['Date', 'Team', 'Opponent', 'Referee', 'TY', 'OY', 'TR', 'OR', 'B365TW',
#        'B365D', 'B365OW', 'Table', 'Venue', 'Result', 'Possesion',
#        'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table', 'Shot on Target',
#        'Shot on Target(%)', 'Goals per Shot', 'Expected Goals', 'Save%',
#        'Clean Sheet', 'Pass Completion %', 'Assists', 'Exp. Assisted Goals',
#        'Expected Assists', 'Tackles Won', '% of Dribblers Tackled', 'Blocks',
#        'Interceptions', 'Error'],
#       dtype='object')

# %%
# df 와 merge하기 위해서 club이름을 다시 설정

# %%
name_mapping = {
    'Arsenal Football Club': 'Arsenal', 
    'Manchester City Football Club': 'Manchester City',
    'Cardiff City': 'Cardiff City', 
    'Association Football Club Bournemouth': 'Bournemouth',
    'Fulham Football Club': 'Fulham', 
    'Crystal Palace Football Club': 'Crystal Palace',
    'Huddersfield Town': 'Huddersfield', 
    'Chelsea Football Club': 'Chelsea',
    'West Ham United Football Club': 'West Ham', 
    'Liverpool Football Club': 'Liverpool',
    'Manchester United Football Club': 'Manchester Utd', 
    'Leicester City': 'Leicester City',
    'Newcastle United Football Club': 'Newcastle Utd',
    'Tottenham Hotspur Football Club': 'Tottenham', 
    'Burnley Football Club': 'Burnley',
    'Southampton FC': 'Southampton', 
    'Watford FC': 'Watford',
    'Brighton and Hove Albion Football Club': 'Brighton & Hove Albion',
    'Wolverhampton Wanderers Football Club': 'Wolverhampton', 
    'Everton Football Club': 'Everton',
    'Norwich City': 'Norwich City', 
    'Sheffield United Football Club': 'Sheffield Utd',
    'Aston Villa Football Club': 'Aston Villa', 
    'Leeds United': 'Leeds United',
    'West Bromwich Albion': 'West Bromwich Albion', 
    'Brentford Football Club': 'Brentford',
    'Nottingham Forest Football Club': 'Nottingham Forest', 
    'Luton Town Football Club': 'Luton Town'
}

# %%
m_merged_df['club_name'] = m_merged_df['club_name'].replace(name_mapping)

# %%
m_merged_df
# Out:
#       game_id       date  club_id  own_goals  own_position  \
# 917   3050167 2018-08-12       11          0          15.0
# 917   3050167 2018-08-12      281          2           3.0
# 2009  3050168 2018-08-11      603          0          17.0
# 2009  3050168 2018-08-11      989          2           5.0
# 918   3050169 2018-08-11      931          0          18.0
# ...       ...        ...      ...        ...           ...
# 1156  4095365 2024-03-16      931          3          12.0
# 225   4095366 2024-03-16     1031          1          17.0
# 225   4095366 2024-03-16      703          1          18.0
# 2004  4095368 2024-03-17      405          1           4.0
# 2004  4095368 2024-03-17      379          1           7.0
#
#          own_manager_name  opponent_id  opponent_goals  opponent_position  \
# 917            Unai Emery          281               2                3.0
# 917         Pep Guardiola           11               0               15.0
# 2009         Neil Warnock          989               2                5.0
# 2009           Eddie Howe          603               0               17.0
# 918     Slavisa Jokanovic          873               2                4.0
# ...                   ...          ...             ...                ...
# 1156          Marco Silva          148               0                5.0
# 225           Rob Edwards          703               1               18.0
# 225   Nuno Espírito Santo         1031               1               17.0
# 2004           Unai Emery          379               1                7.0
# 2004          David Moyes          405               1                4.0
#
#      opponent_manager_name hosting  is_win          club_name
# 917          Pep Guardiola    Home       0            Arsenal
# 917             Unai Emery    Away       1    Manchester City
# 2009            Eddie Howe    Away       0       Cardiff City
# 2009          Neil Warnock    Home       1        Bournemouth
# 918            Roy Hodgson    Home       0             Fulham
# ...                    ...     ...     ...                ...
# 1156      Ange Postecoglou    Home       1             Fulham
# 225    Nuno Espírito Santo    Home       0         Luton Town
# 225            Rob Edwards    Away       0  Nottingham Forest
# 2004           David Moyes    Away       0        Aston Villa
# 2004            Unai Emery    Home       0           West Ham
#
# [4366 rows x 13 columns]

# %%
# 내가 지금까지 club_games랑 games df를 전처리한 건 df DataFrame에 감독이름을 추가하기 위해서

# %%
# 다음은 df dataframe 정리하기

# %%
# 배팅 정보는 확률로 변경

# %%
dropped_df['B365TW'] = (1/dropped_df['B365TW'])*100

# %%
dropped_df['B365D'] = (1/dropped_df['B365D'])*100

# %%
dropped_df['B365OW'] = (1/dropped_df['B365OW'])*100

# %%
dropped_df.columns
# Out:
# Index(['Date', 'Team', 'Opponent', 'Referee', 'TY', 'OY', 'TR', 'OR', 'B365TW',
#        'B365D', 'B365OW', 'Table', 'Venue', 'Result', 'Possesion',
#        'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table', 'Shot on Target',
#        'Shot on Target(%)', 'Goals per Shot', 'Expected Goals', 'Save%',
#        'Clean Sheet', 'Pass Completion %', 'Assists', 'Exp. Assisted Goals',
#        'Expected Assists', 'Tackles Won', '% of Dribblers Tackled', 'Blocks',
#        'Interceptions', 'Error'],
#       dtype='object')

# %%
dropped_df.head()
# Out:
#          Date                    Team        Opponent     Referee  TY  OY  TR  \
# 0  2018-08-10          Leicester City  Manchester Utd  A Marriner   1   2   0
# 1  2018-08-10          Manchester Utd  Leicester City  A Marriner   2   1   0
# 2  2018-08-11             Bournemouth    Cardiff City    K Friend   1   1   0
# 3  2018-08-11  Brighton & Hove Albion         Watford      J Moss   2   2   0
# 4  2018-08-11            Cardiff City     Bournemouth    K Friend   1   1   0
#
#    OR     B365TW      B365D  ...  Clean Sheet  Pass Completion % Assists  \
# 0   0  13.333333  25.641026  ...            0               79.4       0
# 1   0  63.694268  25.641026  ...            0               80.1       1
# 2   0  52.631579  27.777778  ...            1               79.0       2
# 3   0  29.411765  31.250000  ...            0               74.4       0
# 4   0  22.222222  27.777778  ...            0               58.4       0
#
#   Exp. Assisted Goals  Expected Assists  Tackles Won  % of Dribblers Tackled  \
# 0                 0.8               1.0           11                    21.4
# 1                 0.7               0.3           13                    50.0
# 2                 1.3               1.1            5                    47.1
# 3                 0.3               0.2           11                    50.0
# 4                 1.5               1.2           12                    47.6
#
#    Blocks  Interceptions  Error
# 0       8             12      0
# 1      15             17      0
# 2      11              4      0
# 3      14             17      0
# 4      16             15      0
#
# [5 rows x 34 columns]

# %%
dropped_df['Date'] = pd.to_datetime(dropped_df['Date'])

# %%
master_df = pd.merge(m_merged_df[['game_id', 'date', 'club_name', 'club_id', 'opponent_id', 'own_manager_name', 'opponent_manager_name']], dropped_df, \
         left_on=['date', 'club_name'], right_on=['Date', 'Team'])

# %%
master_df = master_df.drop(['date', 'club_name'], axis=1)

# %%
master_df.columns
# Out:
# Index(['game_id', 'club_id', 'opponent_id', 'own_manager_name',
#        'opponent_manager_name', 'Date', 'Team', 'Opponent', 'Referee', 'TY',
#        'OY', 'TR', 'OR', 'B365TW', 'B365D', 'B365OW', 'Table', 'Venue',
#        'Result', 'Possesion', 'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table',
#        'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
#        'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
#        'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
#        '% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error'],
#       dtype='object')

# %%
new_column_order = ['game_id', 'Date', 'Team', 'Opponent', 'club_id', 'opponent_id', 'own_manager_name', 'opponent_manager_name',
       'Referee', 'TY', 'OY', 'TR', 'OR', 'B365TW', 'B365D',
       'B365OW', 'Table', 'Venue', 'Result', 'Possesion', 'Aerial Duels(%)',
       'GF', 'GA', 'Oppo. Table', 'Shot on Target', 'Shot on Target(%)',
       'Goals per Shot', 'Expected Goals', 'Save%', 'Clean Sheet',
       'Pass Completion %', 'Assists', 'Exp. Assisted Goals',
       'Expected Assists', 'Tackles Won', '% of Dribblers Tackled', 'Blocks',
       'Interceptions', 'Error']

# %%
master_df
# Out:
#       game_id  club_id  opponent_id     own_manager_name  \
# 0     3050167       11          281           Unai Emery
# 1     3050167      281           11        Pep Guardiola
# 2     3050168      603          989         Neil Warnock
# 3     3050168      989          603           Eddie Howe
# 4     3050169      931          873    Slavisa Jokanovic
# ...       ...      ...          ...                  ...
# 4361  4095365      931          148          Marco Silva
# 4362  4095366     1031          703          Rob Edwards
# 4363  4095366      703         1031  Nuno Espírito Santo
# 4364  4095368      405          379           Unai Emery
# 4365  4095368      379          405          David Moyes
#
#      opponent_manager_name       Date               Team           Opponent  \
# 0            Pep Guardiola 2018-08-12            Arsenal    Manchester City
# 1               Unai Emery 2018-08-12    Manchester City            Arsenal
# 2               Eddie Howe 2018-08-11       Cardiff City        Bournemouth
# 3             Neil Warnock 2018-08-11        Bournemouth       Cardiff City
# 4              Roy Hodgson 2018-08-11             Fulham     Crystal Palace
# ...                    ...        ...                ...                ...
# 4361      Ange Postecoglou 2024-03-16             Fulham          Tottenham
# 4362   Nuno Espírito Santo 2024-03-16         Luton Town  Nottingham Forest
# 4363           Rob Edwards 2024-03-16  Nottingham Forest         Luton Town
# 4364           David Moyes 2024-03-17        Aston Villa           West Ham
# 4365            Unai Emery 2024-03-17           West Ham        Aston Villa
#
#         Referee  TY  ...  Clean Sheet  Pass Completion %  Assists  \
# 0      M Oliver   2  ...            0               77.1        0
# 1      M Oliver   2  ...            1               81.9        2
# 2      K Friend   1  ...            0               58.4        0
# 3      K Friend   1  ...            1               79.0        2
# 4        M Dean   1  ...            0               85.2        0
# ...         ...  ..  ...          ...                ...      ...
# 4361    R Jones   2  ...            1               75.8        2
# 4362  D England   1  ...            0               78.2        1
# 4363  D England   2  ...            0               68.8        1
# 4364  J Gillett   3  ...            0               85.3        1
# 4365  J Gillett   3  ...            0               72.6        1
#
#       Exp. Assisted Goals  Expected Assists  Tackles Won  \
# 0                     0.5               0.6           14
# 1                     0.5               0.4            5
# 2                     1.5               1.2           12
# 3                     1.3               1.1            5
# 4                     0.5               0.7           19
# ...                   ...               ...          ...
# 4361                  1.5               1.3            9
# 4362                  0.4               0.7            5
# 4363                  1.7               1.4           17
# 4364                  0.5               0.9           10
# 4365                  1.8               1.5            8
#
#       % of Dribblers Tackled Blocks Interceptions  Error
# 0                       40.0     13            12      1
# 1                       28.6     14            12      1
# 2                       47.6     16            15      0
# 3                       47.1     11             4      0
# 4                       42.9      5            15      1
# ...                      ...    ...           ...    ...
# 4361                    53.6     15            13      0
# 4362                    36.4     15             5      0
# 4363                    48.1     14             7      0
# 4364                    53.8      9             3      1
# 4365                    33.3     17             8      0
#
# [4366 rows x 39 columns]

# %%
master_df = master_df[new_column_order]

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4366 entries, 0 to 4365
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 4366 non-null   int64
#  1   Date                    4366 non-null   datetime64[ns]
#  2   Team                    4366 non-null   object
#  3   Opponent                4366 non-null   object
#  4   club_id                 4366 non-null   int64
#  5   opponent_id             4366 non-null   int64
#  6   own_manager_name        4366 non-null   object
#  7   opponent_manager_name   4366 non-null   object
#  8   Referee                 4366 non-null   object
#  9   TY                      4366 non-null   int64
#  10  OY                      4366 non-null   int64
#  11  TR                      4366 non-null   int64
#  12  OR                      4366 non-null   int64
#  13  B365TW                  4366 non-null   float64
#  14  B365D                   4366 non-null   float64
#  15  B365OW                  4366 non-null   float64
#  16  Table                   4366 non-null   int64
#  17  Venue                   4366 non-null   object
#  18  Result                  4366 non-null   object
#  19  Possesion               4366 non-null   int64
#  20  Aerial Duels(%)         4366 non-null   float64
#  21  GF                      4366 non-null   int64
#  22  GA                      4366 non-null   int64
#  23  Oppo. Table             4366 non-null   int64
#  24  Shot on Target          4366 non-null   int64
#  25  Shot on Target(%)       4366 non-null   float64
#  26  Goals per Shot          4366 non-null   float64
#  27  Expected Goals          4366 non-null   float64
#  28  Save%                   4366 non-null   float64
#  29  Clean Sheet             4366 non-null   int64
#  30  Pass Completion %       4366 non-null   float64
#  31  Assists                 4366 non-null   int64
#  32  Exp. Assisted Goals     4366 non-null   float64
#  33  Expected Assists        4366 non-null   float64
#  34  Tackles Won             4366 non-null   int64
#  35  % of Dribblers Tackled  4366 non-null   float64
#  36  Blocks                  4366 non-null   int64
#  37  Interceptions           4366 non-null   int64
#  38  Error                   4366 non-null   int64
# dtypes: datetime64[ns](1), float64(12), int64(19), object(7)
# memory usage: 1.3+ MB

# %%
# master_df 에 더해서

# %%
club_value_by_game = pd.read_csv('./data/mean_value_by_game.csv')

# %%
master_df.head()
# Out:
#    game_id       Date             Team         Opponent  club_id  opponent_id  \
# 0  3050167 2018-08-12          Arsenal  Manchester City       11          281
# 1  3050167 2018-08-12  Manchester City          Arsenal      281           11
# 2  3050168 2018-08-11     Cardiff City      Bournemouth      603          989
# 3  3050168 2018-08-11      Bournemouth     Cardiff City      989          603
# 4  3050169 2018-08-11           Fulham   Crystal Palace      931          873
#
#     own_manager_name opponent_manager_name   Referee  TY  ...  Clean Sheet  \
# 0         Unai Emery         Pep Guardiola  M Oliver   2  ...            0
# 1      Pep Guardiola            Unai Emery  M Oliver   2  ...            1
# 2       Neil Warnock            Eddie Howe  K Friend   1  ...            0
# 3         Eddie Howe          Neil Warnock  K Friend   1  ...            1
# 4  Slavisa Jokanovic           Roy Hodgson    M Dean   1  ...            0
#
#    Pass Completion %  Assists  Exp. Assisted Goals  Expected Assists  \
# 0               77.1        0                  0.5               0.6
# 1               81.9        2                  0.5               0.4
# 2               58.4        0                  1.5               1.2
# 3               79.0        2                  1.3               1.1
# 4               85.2        0                  0.5               0.7
#
#    Tackles Won  % of Dribblers Tackled Blocks Interceptions  Error
# 0           14                    40.0     13            12      1
# 1            5                    28.6     14            12      1
# 2           12                    47.6     16            15      0
# 3            5                    47.1     11             4      0
# 4           19                    42.9      5            15      1
#
# [5 rows x 39 columns]

# %%
club_value_by_game.head()
# Out:
#    game_id  player_club_id  market_value_in_eur
# 0  3050167              11         3.064286e+07
# 1  3050167             281         6.357143e+07
# 2  3050168             603         2.196429e+06
# 3  3050168             989         6.035714e+06
# 4  3050169             873         1.117857e+07

# %%
master_df = pd.merge(master_df, club_value_by_game, left_on=['game_id', 'club_id'], right_on=['game_id', 'player_club_id'])

# %%
master_df
# Out:
#       game_id       Date               Team           Opponent  club_id  \
# 0     3050167 2018-08-12            Arsenal    Manchester City       11
# 1     3050167 2018-08-12    Manchester City            Arsenal      281
# 2     3050168 2018-08-11       Cardiff City        Bournemouth      603
# 3     3050168 2018-08-11        Bournemouth       Cardiff City      989
# 4     3050169 2018-08-11             Fulham     Crystal Palace      931
# ...       ...        ...                ...                ...      ...
# 4361  4095365 2024-03-16             Fulham          Tottenham      931
# 4362  4095366 2024-03-16         Luton Town  Nottingham Forest     1031
# 4363  4095366 2024-03-16  Nottingham Forest         Luton Town      703
# 4364  4095368 2024-03-17        Aston Villa           West Ham      405
# 4365  4095368 2024-03-17           West Ham        Aston Villa      379
#
#       opponent_id     own_manager_name opponent_manager_name    Referee  TY  \
# 0             281           Unai Emery         Pep Guardiola   M Oliver   2
# 1              11        Pep Guardiola            Unai Emery   M Oliver   2
# 2             989         Neil Warnock            Eddie Howe   K Friend   1
# 3             603           Eddie Howe          Neil Warnock   K Friend   1
# 4             873    Slavisa Jokanovic           Roy Hodgson     M Dean   1
# ...           ...                  ...                   ...        ...  ..
# 4361          148          Marco Silva      Ange Postecoglou    R Jones   2
# 4362          703          Rob Edwards   Nuno Espírito Santo  D England   1
# 4363         1031  Nuno Espírito Santo           Rob Edwards  D England   2
# 4364          379           Unai Emery           David Moyes  J Gillett   3
# 4365          405          David Moyes            Unai Emery  J Gillett   3
#
#       ...  Assists  Exp. Assisted Goals  Expected Assists  Tackles Won  \
# 0     ...        0                  0.5               0.6           14
# 1     ...        2                  0.5               0.4            5
# 2     ...        0                  1.5               1.2           12
# 3     ...        2                  1.3               1.1            5
# 4     ...        0                  0.5               0.7           19
# ...   ...      ...                  ...               ...          ...
# 4361  ...        2                  1.5               1.3            9
# 4362  ...        1                  0.4               0.7            5
# 4363  ...        1                  1.7               1.4           17
# 4364  ...        1                  0.5               0.9           10
# 4365  ...        1                  1.8               1.5            8
#
#       % of Dribblers Tackled  Blocks  Interceptions Error player_club_id  \
# 0                       40.0      13             12     1             11
# 1                       28.6      14             12     1            281
# 2                       47.6      16             15     0            603
# 3                       47.1      11              4     0            989
# 4                       42.9       5             15     1            931
# ...                      ...     ...            ...   ...            ...
# 4361                    53.6      15             13     0            931
# 4362                    36.4      15              5     0           1031
# 4363                    48.1      14              7     0            703
# 4364                    53.8       9              3     1            405
# 4365                    33.3      17              8     0            379
#
#       market_value_in_eur
# 0            3.064286e+07
# 1            6.357143e+07
# 2            2.196429e+06
# 3            6.035714e+06
# 4            1.060714e+07
# ...                   ...
# 4361         1.681250e+07
# 4362         5.200000e+06
# 4363         1.485714e+07
# 4364         3.106667e+07
# 4365         2.563571e+07
#
# [4366 rows x 41 columns]

# %%
master_df.columns
# Out:
# Index(['game_id', 'Date', 'Team', 'Opponent', 'club_id', 'opponent_id',
#        'own_manager_name', 'opponent_manager_name', 'Referee', 'TY', 'OY',
#        'TR', 'OR', 'B365TW', 'B365D', 'B365OW', 'Table', 'Venue', 'Result',
#        'Possesion', 'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table',
#        'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
#        'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
#        'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
#        '% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error',
#        'player_club_id', 'market_value_in_eur'],
#       dtype='object')

# %%
master_df = master_df.drop('player_club_id', axis=1)

# %%
master_df.columns
# Out:
# Index(['game_id', 'Date', 'Team', 'Opponent', 'club_id', 'opponent_id',
#        'own_manager_name', 'opponent_manager_name', 'Referee', 'TY', 'OY',
#        'TR', 'OR', 'B365TW', 'B365D', 'B365OW', 'Table', 'Venue', 'Result',
#        'Possesion', 'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table',
#        'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
#        'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
#        'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
#        '% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error',
#        'market_value_in_eur'],
#       dtype='object')

# %%
master_df.isnull().sum()
# Out:
# game_id                   0
# Date                      0
# Team                      0
# Opponent                  0
# club_id                   0
# opponent_id               0
# own_manager_name          0
# opponent_manager_name     0
# Referee                   0
# TY                        0
# OY                        0
# TR                        0
# OR                        0
# B365TW                    0
# B365D                     0
# B365OW                    0
# Table                     0
# Venue                     0
# Result                    0
# Possesion                 0
# Aerial Duels(%)           0
# GF                        0
# GA                        0
# Oppo. Table               0
# Shot on Target            0
# Shot on Target(%)         0
# Goals per Shot            0
# Expected Goals            0
# Save%                     0
# Clean Sheet               0
# Pass Completion %         0
# Assists                   0
# Exp. Assisted Goals       0
# Expected Assists          0
# Tackles Won               0
# % of Dribblers Tackled    0
# Blocks                    0
# Interceptions             0
# Error                     0
# market_value_in_eur       0
# dtype: int64

# %%
# 이동평균을 할 컬럼 선정

# %%
# 이동평균을 하면 안되는 컬럼 : 
len(['club_id', 'opponent_id', 'B365TW', 'B365D', 'B365OW', 'Table', 'Oppo. Table', 
'own_manager_name', 'opponent_manager_name', 'Venue', 'Result', 'Referee'])
# Out:
# 12

# %%
# 이동평균 해야하는 컬럼 : 
len(['TY', 'OY', 'TR', 'OR', 'Possesion', 'Aerial Duels(%)', 'GF', 'GA',
'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
'% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error', 'market_value_in_eur'])
# Out:
# 24

# %%
# 위의 컬럼 합쳐서 총 36개 + game_id, Date 하면 총 38개 -> 개수 맞음

# %%
# GA를 넣어야 하는지 약간 의심스럼움, GA는 우리팀 입장에선 당한? 골 수 이지만 이게 상대팀에 따라서 달라지니까 그런데 opponent_id가 있으니까
# 같이 있어도 상관 없을 것 같기도 하고 일단 모델링 하고 Feature importance를 보고 판단하자 
# 아니면 튜터님한테 말해보고 알려달라고 하자

# %%
master_df.columns
# Out:
# Index(['game_id', 'Date', 'Team', 'Opponent', 'club_id', 'opponent_id',
#        'own_manager_name', 'opponent_manager_name', 'Referee', 'TY', 'OY',
#        'TR', 'OR', 'B365TW', 'B365D', 'B365OW', 'Table', 'Venue', 'Result',
#        'Possesion', 'Aerial Duels(%)', 'GF', 'GA', 'Oppo. Table',
#        'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
#        'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
#        'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
#        '% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error',
#        'market_value_in_eur'],
#       dtype='object')

# %%
master_df = master_df.sort_values(['club_id', 'Date'])

# %%
not_app_features = ['game_id', 'club_id', 'opponent_id', 'B365TW', 'B365D', 'B365OW', 'Table', 'Oppo. Table', 
'own_manager_name', 'opponent_manager_name', 'Venue', 'Result', 'Referee']

# %%
# 'Date', 'club_id' 는 학습하는 컬럼은 아니지만 인덱스를 위해 남겨두어야 하는 컬럼
# game_id가 아니라 club_id를 남겨두는 이유는 클럽별로 묶은 후 이동평균을 해야하기 때문 
# 그냥 하면 다른팀의 이전경기의 평균값을 가져오게 되므로 우선 club별로 묶은 후 이동평균을 해야하기 때문에 index로 club_id를 남겨둠
# 그래서 위에 이동평균 적용하면 안되는 컬럼에도 들어가고 여기 list에도 들어오게 됨
# game_id는 현재 여기서는 필요없어서 자연스럽게 적지 않음

app_features = ['Date', 'club_id', 'TY', 'OY', 'TR', 'OR', 'Possesion', 'Aerial Duels(%)', 'GF', 'GA',
'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
'% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error', 'market_value_in_eur']

# %%
# 'game_id', 'Date', 'club_id' index 빼고 모델링 할 컬럼의 리스트

selected_col = ['TY', 'OY', 'TR', 'OR', 'Possesion', 'Aerial Duels(%)', 'GF', 'GA',
'Shot on Target', 'Shot on Target(%)', 'Goals per Shot',
'Expected Goals', 'Save%', 'Clean Sheet', 'Pass Completion %',
'Assists', 'Exp. Assisted Goals', 'Expected Assists', 'Tackles Won',
'% of Dribblers Tackled', 'Blocks', 'Interceptions', 'Error', 'market_value_in_eur']

# %%
master_df[app_features]
# Out:
#            Date  club_id  TY  OY  TR  OR  Possesion  Aerial Duels(%)  GF  GA  \
# 0    2018-08-12       11   2   2   0   0         42             63.6   0   2
# 27   2018-08-18       11   2   0   0   0         38             44.4   2   3
# 40   2018-08-25       11   1   3   0   0         61             50.0   3   1
# 65   2018-09-02       11   4   3   0   0         72             47.8   3   2
# 91   2018-09-15       11   0   0   0   0         63             50.0   2   1
# ...         ...      ...  ..  ..  ..  ..        ...              ...  ..  ..
# 4275 2024-02-10     1237   3   2   0   0         48             23.1   1   2
# 4296 2024-02-18     1237   4   1   0   1         79             70.8   5   0
# 4306 2024-02-24     1237   2   3   1   0         64             64.3   1   1
# 4325 2024-03-02     1237   2   1   0   0         70             58.6   0   3
# 4345 2024-03-10     1237   4   4   0   0         63             60.0   1   0
#
#       ...  Pass Completion %  Assists  Exp. Assisted Goals  Expected Assists  \
# 0     ...               77.1        0                  0.5               0.6
# 27    ...               81.2        1                  2.3               1.4
# 40    ...               82.2        2                  1.6               1.4
# 65    ...               83.3        3                  1.1               1.0
# 91    ...               83.0        0                  0.8               1.1
# ...   ...                ...      ...                  ...               ...
# 4275  ...               80.2        0                  0.4               0.4
# 4296  ...               91.0        2                  1.8               2.3
# 4306  ...               87.4        1                  1.2               1.0
# 4325  ...               86.3        0                  1.1               1.4
# 4345  ...               89.7        0                  0.2               0.5
#
#       Tackles Won  % of Dribblers Tackled  Blocks  Interceptions  Error  \
# 0              14                    40.0      13             12      1
# 27              6                    25.0      12             12      2
# 40             11                    29.2      14              6      1
# 65              9                    50.0       6             11      2
# 91              6                    50.0       7              7      0
# ...           ...                     ...     ...            ...    ...
# 4275           10                    35.3      20             13      0
# 4296           10                    47.1      10              4      0
# 4306            8                    25.0       6              4      0
# 4325           12                    73.3      15              8      3
# 4345            5                    38.5       9              5      1
#
#       market_value_in_eur
# 0            3.064286e+07
# 27           3.235714e+07
# 40           3.021429e+07
# 65           3.235714e+07
# 91           3.235714e+07
# ...                   ...
# 4275         1.996667e+07
# 4296         2.200000e+07
# 4306         1.906250e+07
# 4325         1.890625e+07
# 4345         1.906250e+07
#
# [4366 rows x 26 columns]

# %%
moving_avg_df = master_df[app_features].groupby('club_id')[selected_col].rolling(window=3).mean().reset_index(drop=True)

# %%
moving_avg_df
# Out:
#             TY        OY        TR        OR  Possesion  Aerial Duels(%)  \
# 0          NaN       NaN       NaN       NaN        NaN              NaN
# 1          NaN       NaN       NaN       NaN        NaN              NaN
# 2     1.666667  1.666667  0.000000  0.000000  47.000000        52.666667
# 3     2.333333  2.000000  0.000000  0.000000  57.000000        47.400000
# 4     1.666667  2.000000  0.000000  0.000000  65.333333        49.266667
# ...        ...       ...       ...       ...        ...              ...
# 4361  2.000000  2.333333  0.000000  0.000000  58.333333        45.200000
# 4362  2.666667  2.000000  0.000000  0.333333  65.000000        52.133333
# 4363  3.000000  2.000000  0.333333  0.333333  63.666667        52.733333
# 4364  2.666667  1.666667  0.333333  0.333333  71.000000        64.566667
# 4365  2.666667  2.666667  0.333333  0.000000  65.666667        60.966667
#
#             GF        GA  Shot on Target  Shot on Target(%)  ...  \
# 0          NaN       NaN             NaN                NaN  ...
# 1          NaN       NaN             NaN                NaN  ...
# 2     1.666667  2.000000        6.333333          44.033333  ...
# 3     2.666667  2.000000        9.000000          54.500000  ...
# 4     2.666667  1.333333        7.666667          46.733333  ...
# ...        ...       ...             ...                ...  ...
# 4361  1.666667  2.333333        3.333333          36.133333  ...
# 4362  3.333333  1.000000        5.666667          41.233333  ...
# 4363  2.333333  1.000000        6.000000          35.966667  ...
# 4364  2.000000  1.333333        7.000000          33.733333  ...
# 4365  0.666667  1.333333        5.000000          31.233333  ...
#
#       Pass Completion %   Assists  Exp. Assisted Goals  Expected Assists  \
# 0                   NaN       NaN                  NaN               NaN
# 1                   NaN       NaN                  NaN               NaN
# 2             80.166667  1.000000             1.466667          1.133333
# 3             82.233333  2.000000             1.666667          1.266667
# 4             82.833333  1.666667             1.166667          1.166667
# ...                 ...       ...                  ...               ...
# 4361          83.266667  1.333333             0.733333          0.633333
# 4362          88.133333  2.000000             1.200000          1.233333
# 4363          86.200000  1.000000             1.133333          1.233333
# 4364          88.233333  1.000000             1.366667          1.566667
# 4365          87.800000  0.333333             0.833333          0.966667
#
#       Tackles Won  % of Dribblers Tackled     Blocks  Interceptions     Error  \
# 0             NaN                     NaN        NaN            NaN       NaN
# 1             NaN                     NaN        NaN            NaN       NaN
# 2       10.333333               31.400000  13.000000      10.000000  1.333333
# 3        8.666667               34.733333  10.666667       9.666667  1.666667
# 4        8.666667               43.066667   9.000000       8.000000  1.000000
# ...           ...                     ...        ...            ...       ...
# 4361    12.666667               45.900000  14.666667       9.666667  1.333333
# 4362    11.666667               45.400000  12.333333       9.333333  0.666667
# 4363     9.333333               35.800000  12.000000       7.000000  0.000000
# 4364    10.000000               48.466667  10.333333       5.333333  1.000000
# 4365     8.333333               45.600000  10.000000       5.666667  1.333333
#
#       market_value_in_eur
# 0                     NaN
# 1                     NaN
# 2            3.107143e+07
# 3            3.164286e+07
# 4            3.164286e+07
# ...                   ...
# 4361         1.891597e+07
# 4362         2.044722e+07
# 4363         2.034306e+07
# 4364         1.998958e+07
# 4365         1.901042e+07
#
# [4366 rows x 24 columns]

# %%
m_final_df = pd.concat([master_df[not_app_features], moving_avg_df], axis=1)

# %%
cleaned_final_df = m_final_df.dropna()

# %%
cleaned_final_df
# Out:
#       game_id  club_id  opponent_id     B365TW      B365D     B365OW  Table  \
# 27    3050180       11          631  22.222222  25.000000  55.555556     17
# 40    3050187       11          379  73.529412  18.181818  11.111111      9
# 65    3050199       11          603  63.694268  23.094688  15.384615      9
# 91    3050212       11          762  52.631579  26.315789  23.809524      7
# 100   3050217       11           29  69.444444  20.000000  13.333333      6
# ...       ...      ...          ...        ...        ...        ...    ...
# 4275  4095317     1237          148  26.315789  23.809524  55.555556      9
# 4296  4095328     1237          350  61.728395  23.809524  20.000000      7
# 4306  4095333     1237           29  54.644809  26.315789  23.809524      7
# 4325  4095343     1237          931  38.022814  27.777778  39.215686      9
# 4345  4095353     1237          703  55.555556  25.000000  25.000000      8
#
#       Oppo. Table  own_manager_name opponent_manager_name  ...  \
# 27              3        Unai Emery        Maurizio Sarri  ...
# 40             20        Unai Emery     Manuel Pellegrini  ...
# 65             16        Unai Emery          Neil Warnock  ...
# 91             19        Unai Emery        Rafael Benítez  ...
# 100            12        Unai Emery           Marco Silva  ...
# ...           ...               ...                   ...  ...
# 4275            4  Roberto De Zerbi      Ange Postecoglou  ...
# 4296           20  Roberto De Zerbi          Chris Wilder  ...
# 4306           15  Roberto De Zerbi            Sean Dyche  ...
# 4325           12  Roberto De Zerbi           Marco Silva  ...
# 4345           17  Roberto De Zerbi   Nuno Espírito Santo  ...
#
#      Pass Completion %   Assists Exp. Assisted Goals  Expected Assists  \
# 27           80.266667  2.333333            1.766667          1.266667
# 40           83.500000  1.000000            0.766667          0.566667
# 65           85.000000  2.666667            1.700000          1.366667
# 91           79.266667  0.666667            0.700000          0.600000
# 100          81.000000  1.000000            0.766667          0.866667
# ...                ...       ...                 ...               ...
# 4275         82.133333  0.333333            1.166667          0.866667
# 4296         72.566667  0.333333            0.533333          0.633333
# 4306         80.066667  1.333333            0.966667          0.800000
# 4325         83.633333  1.333333            1.600000          1.566667
# 4345         85.166667  1.333333            1.600000          1.166667
#
#       Tackles Won  % of Dribblers Tackled     Blocks  Interceptions     Error  \
# 27       9.666667               44.833333  15.000000      13.333333  1.000000
# 40       6.666667               46.300000  12.333333       7.333333  0.666667
# 65       7.666667               48.400000   7.000000      10.666667  0.666667
# 91       6.000000               40.766667  12.333333       8.333333  0.333333
# 100      4.000000               24.766667  10.333333       9.333333  1.333333
# ...           ...                     ...        ...            ...       ...
# 4275    10.333333               39.966667  10.333333       6.333333  0.666667
# 4296    12.000000               43.833333  15.333333       6.666667  0.333333
# 4306    11.000000               45.566667   9.000000      12.666667  0.666667
# 4325    10.000000               49.600000  10.333333       8.333333  1.000000
# 4345    12.666667               40.133333  11.666667      10.333333  0.666667
#
#       market_value_in_eur
# 27           2.927473e+07
# 40           3.088889e+07
# 65           3.154487e+07
# 91           2.303333e+07
# 100          2.450286e+07
# ...                   ...
# 4275         1.349762e+07
# 4296         1.314524e+07
# 4306         1.382063e+07
# 4325         1.547414e+07
# 4345         1.754464e+07
#
# [4310 rows x 37 columns]

# %%
#cleaned_final_df.to_csv('./data/add_oppo_df.csv', index=False)
