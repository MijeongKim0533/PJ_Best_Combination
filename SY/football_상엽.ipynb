# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
players = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/players.csv')
clubs = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/clubs.csv')
valuations = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/player_valuations.csv')
games = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/games.csv')
lineup = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/game_lineups.csv')

# %%
players = players.drop(['image_url', 'url'], axis=1)
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30499 entries, 0 to 30498
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             30499 non-null  int64
#  1   first_name                            28512 non-null  object
#  2   last_name                             30499 non-null  object
#  3   name                                  30499 non-null  object
#  4   last_season                           30499 non-null  int64
#  5   current_club_id                       30499 non-null  int64
#  6   player_code                           30499 non-null  object
#  7   country_of_birth                      27779 non-null  object
#  8   city_of_birth                         28302 non-null  object
#  9   country_of_citizenship                29920 non-null  object
#  10  date_of_birth                         30454 non-null  object
# ...

# %%
valuations
# Out:
#         player_id        date  market_value_in_eur  current_club_id  \
# 0          405973  2000-01-20               150000             3057
# 1          342216  2001-07-20               100000             1241
# 2            3132  2003-12-09               400000              126
# 3            6893  2003-12-15               900000              984
# 4              10  2004-10-04              7000000              398
# ...           ...         ...                  ...              ...
# 466897     937958  2024-03-21             75000000              131
# 466898     938158  2024-03-21              7500000              131
# 466899     941869  2024-03-21               500000             3709
# 466900     962110  2024-03-21             25000000              131
# 466901     991268  2024-03-21             40000000             1108
#
#        player_club_domestic_competition_id
# 0                                      BE1
# 1                                      SC1
# ...

# %%
merged_df = pd.merge(valuations, players, on='player_id')
merged_df
# Out:
#         player_id        date  market_value_in_eur_x  current_club_id_x  \
# 0          405973  2000-01-20                 150000               3057
# 1          405973  2016-02-07                 250000               3057
# 2          405973  2016-07-15                 250000               3057
# 3          405973  2017-01-01                 150000               3057
# 4          405973  2018-09-11                  75000               3057
# ...           ...         ...                    ...                ...
# 466897    1041334  2024-03-18                  50000              48726
# 466898    1057222  2024-03-18                 200000                660
# 466899    1158515  2024-03-18                 100000              60551
# 466900     903693  2024-03-19                1000000                583
# 466901    1127413  2024-03-20                 100000               2410
#
#        player_club_domestic_competition_id   first_name last_name  \
# ...

# %%
merged_df[merged_df['player_id'] == 91845]
# Out:
#         player_id        date  market_value_in_eur_x  current_club_id_x  \
# 198487      91845  2010-08-01                 150000                148
# 198488      91845  2010-08-06                 500000                148
# 198489      91845  2010-11-23                1500000                148
# 198490      91845  2011-01-12                3000000                148
# 198491      91845  2011-06-29                3000000                148
# 198492      91845  2011-08-15                4500000                148
# 198493      91845  2012-01-23                4500000                148
# 198494      91845  2012-06-29                4500000                148
# 198495      91845  2012-10-26                8000000                148
# 198496      91845  2013-01-13                8000000                148
# 198497      91845  2013-03-11               13000000                148
# 198498      91845  2013-06-30               14000000                148
# ...

# %%
lineup
# Out:
#                           game_lineups_id        date  game_id  player_id  \
# 0        b2dbe01c3656b06c8e23e9de714e26bb  2013-07-27  2317258       1443
# 1        b50a3ec6d52fd1490aab42042ac4f738  2013-07-27  2317258       5017
# 2        7d890e6d0ff8af84b065839966a0ec81  2013-07-27  2317258       9602
# 3        8c355268678b9bbc7084221b1f0fde36  2013-07-27  2317258      12282
# 4        76193074d549e5fdce4cdcbba0d66247  2013-07-27  2317258      25427
# ...                                   ...         ...      ...        ...
# 2145217  8f1390a3d67394d1387061e3e8d8b33a  2023-05-24  4080529     543771
# 2145218  6038e2ed925b06aed10a1a5ee017cf1a  2023-05-24  4080529     602124
# 2145219  59961ac7781642d465167882867b65a8  2023-05-24  4080529     780136
# 2145220  ea8baaec103816bbdff7ba7703ad4d9e  2023-05-24  4080529     969192
# 2145221  90937b423ad3c23de1756275f2ead2bd  2023-05-24  4080529     988977
#
#          club_id           player_name             type            position  \
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67421 entries, 0 to 67420
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 67421 non-null  int64
#  1   competition_id          67421 non-null  object
#  2   season                  67421 non-null  int64
#  3   round                   67421 non-null  object
#  4   date                    67421 non-null  object
#  5   home_club_id            67421 non-null  int64
#  6   away_club_id            67421 non-null  int64
#  7   home_club_goals         67421 non-null  int64
#  8   away_club_goals         67421 non-null  int64
#  9   home_club_position      47449 non-null  float64
#  10  away_club_position      47449 non-null  float64
#  11  home_club_manager_name  66675 non-null  object
#  12  away_club_manager_name  66675 non-null  object
#  13  stadium                 67207 non-null  object
# ...

# %%
clubs
# Out:
#      club_id             club_code                               name  \
# 0        105       sv-darmstadt-98   Sportverein Darmstadt 1898 e. V.
# 1      11127     ural-ekaterinburg              FK Ural Yekaterinburg
# 2        114     besiktas-istanbul          Beşiktaş Jimnastik Kulübü
# 3         12                as-rom         Associazione Sportiva Roma
# 4        148     tottenham-hotspur    Tottenham Hotspur Football Club
# ..       ...                   ...                                ...
# 421    68608      cf-os-belenenses                   CF Os Belenenses
# 422      724           fc-volendam             Football Club Volendam
# 423      800      atalanta-bergamo  Atalanta Bergamasca Calcio S.p.a.
# 424      979         moreirense-fc           Moreirense Futebol Clube
# 425      984  west-bromwich-albion               West Bromwich Albion
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# ...

# %%
kplayers = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/kplayers.csv')
kplayers
# Out:
#     player_id  first_name last_name              name  last_season  \
# 0        1772       Du-ri       Cha         Du-ri Cha         2012
# 1        4592     Ji-sung      Park      Ji-sung Park         2013
# 2       30982   Chu-young      Park    Chu-young Park         2013
# 3       81796  Sung-yueng        Ki     Sung-yueng Ki         2019
# 4       81801  Chung-yong       Lee    Chung-yong Lee         2017
# 5       91841    Ja-cheol       Koo      Ja-cheol Koo         2018
# 6       91845   Heung-min       Son     Heung-min Son         2023
# 7      111900       Ju-ho      Park        Ju-ho Park         2016
# 8      114831   Byung-soo       Yoo     Byung-soo Yoo         2015
# 9      126638    Jeong-ho      Hong     Jeong-ho Hong         2015
# 10     126643  Seok-yeong       Yun    Seok-yeong Yun         2016
# 11     128375    Bo-kyung       Kim      Bo-kyung Kim         2013
# 12     129990    Hyun-jun       Suk      Hyun-jun Suk         2021
# ...

# %%
club_games = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/club_games.csv')
club_games
# Out:
#         game_id  club_id  own_goals  own_position        own_manager_name  \
# 0       2320450     1468          0           NaN       Holger Bachthaler
# 1       2320460        1          3           NaN         Jürgen Luginger
# 2       2320472     2036          4           NaN           Frank Schmidt
# 3       2321044       16          2           1.0            Jürgen Klopp
# 4       2321060       23          0          18.0    Torsten Lieberknecht
# ...         ...      ...        ...           ...                     ...
# 134837  3142950      681          0           NaN         Imanol Alguacil
# 134838  3148382      150          1           NaN           Quique Setién
# 134839  3153158      418          1           NaN         Santiago Solari
# 134840  3307741    36661          1           NaN      Aleksandr Gorshkov
# 134841  3520159    50600          0           NaN  Aleksandr Kishinevskiy
#
#         opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# ...
