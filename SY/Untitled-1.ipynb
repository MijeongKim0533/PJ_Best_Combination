# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
players = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/players.csv')
clubs = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/clubs.csv')
valuations = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/player_valuations.csv')
games = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/games.csv')
lineup = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/game_lineups.csv')
club_games = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/club_games.csv')
game_events = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/game_events.csv')
competitions = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/competitions.csv')
appearances = pd.read_csv('C:/Users/parks/OneDrive/바탕 화면/DATASET/Football/appearances.csv')

# %%
competitions = competitions.drop('url', axis=1)
competitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   competition_id            43 non-null     object
#  1   competition_code          43 non-null     object
#  2   name                      43 non-null     object
#  3   sub_type                  43 non-null     object
#  4   type                      43 non-null     object
#  5   country_id                43 non-null     int64
#  6   country_name              36 non-null     object
#  7   domestic_league_code      36 non-null     object
#  8   confederation             43 non-null     object
#  9   is_major_national_league  43 non-null     bool
# dtypes: bool(1), int64(1), object(8)
# memory usage: 3.2+ KB

# %%
competitions['competition_id'].unique()
# Out:
# array(['CIT', 'NLSC', 'GRP', 'POSU', 'RUSS', 'SUC', 'USC', 'DK1', 'EL',
#        'ES1', 'FR1', 'IT1', 'NL1', 'RUP', 'PO1', 'BESC', 'GB1', 'ELQ',
#        'CGB', 'DKP', 'ECLQ', 'FAC', 'NLP', 'UKRS', 'UKR1', 'CDR', 'CL',
#        'GR1', 'TR1', 'POCP', 'GBCS', 'KLUB', 'L1', 'RU1', 'SC1', 'SCI',
#        'BE1', 'CLQ', 'DFL', 'SFA', 'UKRP', 'DFB', 'FRCH'], dtype=object)

# %%
appearances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1556969 entries, 0 to 1556968
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   appearance_id           1556969 non-null  object
#  1   game_id                 1556969 non-null  int64
#  2   player_id               1556969 non-null  int64
#  3   player_club_id          1556969 non-null  int64
#  4   player_current_club_id  1556969 non-null  int64
#  5   date                    1556969 non-null  object
#  6   player_name             1556963 non-null  object
#  7   competition_id          1556969 non-null  object
#  8   yellow_cards            1556969 non-null  int64
#  9   red_cards               1556969 non-null  int64
#  10  goals                   1556969 non-null  int64
#  11  assists                 1556969 non-null  int64
#  12  minutes_played          1556969 non-null  int64
# dtypes: int64(9), object(4)
# ...

# %%
games = games.drop('url', axis=1)
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67421 entries, 0 to 67420
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 67421 non-null  int64
#  1   competition_id          67421 non-null  object
#  2   season                  67421 non-null  int64
#  3   round                   67421 non-null  object
#  4   date                    67421 non-null  object
#  5   home_club_id            67421 non-null  int64
#  6   away_club_id            67421 non-null  int64
#  7   home_club_goals         67421 non-null  int64
#  8   away_club_goals         67421 non-null  int64
#  9   home_club_position      47449 non-null  float64
#  10  away_club_position      47449 non-null  float64
#  11  home_club_manager_name  66675 non-null  object
#  12  away_club_manager_name  66675 non-null  object
#  13  stadium                 67207 non-null  object
# ...

# %%
df = pd.merge(games, competitions, on='competition_id', how='left')
df
# Out:
#        game_id competition_id  season                     round        date  \
# 0      2321044             L1    2013               2. Matchday  2013-08-18
# 1      2321060             L1    2013               3. Matchday  2013-08-25
# 2      2321086             L1    2013               6. Matchday  2013-09-21
# 3      2321152             L1    2013              11. Matchday  2013-11-02
# 4      2321205             L1    2013              17. Matchday  2013-12-21
# ...        ...            ...     ...                       ...         ...
# 67416  2629035            NLP    2015               Third Round  2015-10-27
# 67417  3092951            CLQ    2018  Qualifying Round 2nd leg  2018-08-29
# 67418  4164101            CGB    2023              Second Round  2023-08-29
# 67419  3143618            FAC    2018        Third Round Replay  2019-01-15
# 67420  4233201            SFA    2023              Fourth Round  2024-01-20
#
# ...

# %%
df['name'].unique()
# Out:
# array(['bundesliga', 'premier-liga', 'jupiler-pro-league', 'ligue-1',
#        'premier-league', 'scottish-premiership', 'liga-portugal-bwin',
#        'laliga', 'eredivisie', 'super-lig', 'super-league-1', 'serie-a',
#        'allianz-cup', 'europa-league', 'ukrainian-cup',
#        'uefa-champions-league', 'copa-del-rey', 'italy-cup', 'fa-cup',
#        'kypello-elladas', 'community-shield',
#        'uefa-champions-league-qualifikation', 'toto-knvb-beker',
#        'superligaen', 'dfb-pokal', 'russian-cup', 'sydbank-pokalen',
#        'europa-league-qualifikation', 'supertaca-candido-de-oliveira',
#        'sfa-cup', 'supercopa', 'fifa-klub-wm', 'efl-cup',
#        'uefa-europa-conference-league-qualifikation', 'uefa-super-cup',
#        'supercoppa-italiana', 'dfl-supercup', 'trophee-des-champions',
#        'ukrainian-super-cup', 'russian-super-cup', 'johan-cruijff-schaal',
#        'belgian-supercup'], dtype=object)

# %%
df[df['sub_type'] != 'fifa_club_world_cup']
# Out:
#        game_id competition_id  season                     round        date  \
# 0      2321044             L1    2013               2. Matchday  2013-08-18
# 1      2321060             L1    2013               3. Matchday  2013-08-25
# 2      2321086             L1    2013               6. Matchday  2013-09-21
# 3      2321152             L1    2013              11. Matchday  2013-11-02
# 4      2321205             L1    2013              17. Matchday  2013-12-21
# ...        ...            ...     ...                       ...         ...
# 67416  2629035            NLP    2015               Third Round  2015-10-27
# 67417  3092951            CLQ    2018  Qualifying Round 2nd leg  2018-08-29
# 67418  4164101            CGB    2023              Second Round  2023-08-29
# 67419  3143618            FAC    2018        Third Round Replay  2019-01-15
# 67420  4233201            SFA    2023              Fourth Round  2024-01-20
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67421 entries, 0 to 67420
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   game_id                   67421 non-null  int64
#  1   competition_id            67421 non-null  object
#  2   season                    67421 non-null  int64
#  3   round                     67421 non-null  object
#  4   date                      67421 non-null  object
#  5   home_club_id              67421 non-null  int64
#  6   away_club_id              67421 non-null  int64
#  7   home_club_goals           67421 non-null  int64
#  8   away_club_goals           67421 non-null  int64
#  9   home_club_position        47449 non-null  float64
#  10  away_club_position        47449 non-null  float64
#  11  home_club_manager_name    66675 non-null  object
#  12  away_club_manager_name    66675 non-null  object
# ...

# %%
clubs = clubs.drop(['url', 'filename'], axis=1)
clubs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club_id                  426 non-null    int64
#  1   club_code                426 non-null    object
#  2   name                     426 non-null    object
#  3   domestic_competition_id  426 non-null    object
#  4   total_market_value       0 non-null      float64
#  5   squad_size               426 non-null    int64
#  6   average_age              388 non-null    float64
#  7   foreigners_number        426 non-null    int64
#  8   foreigners_percentage    378 non-null    float64
#  9   national_team_players    426 non-null    int64
#  10  stadium_name             426 non-null    object
#  11  stadium_seats            426 non-null    int64
#  12  net_transfer_record      426 non-null    object
#  13  coach_name               0 non-null      float64
# ...

# %%
clubs
# Out:
#      club_id             club_code                               name  \
# 0        105       sv-darmstadt-98   Sportverein Darmstadt 1898 e. V.
# 1      11127     ural-ekaterinburg              FK Ural Yekaterinburg
# 2        114     besiktas-istanbul          Beşiktaş Jimnastik Kulübü
# 3         12                as-rom         Associazione Sportiva Roma
# 4        148     tottenham-hotspur    Tottenham Hotspur Football Club
# ..       ...                   ...                                ...
# 421    68608      cf-os-belenenses                   CF Os Belenenses
# 422      724           fc-volendam             Football Club Volendam
# 423      800      atalanta-bergamo  Atalanta Bergamasca Calcio S.p.a.
# 424      979         moreirense-fc           Moreirense Futebol Clube
# 425      984  west-bromwich-albion               West Bromwich Albion
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# ...

# %%
clubs['total_market_value'].unique()
# Out:
# array([nan])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67421 entries, 0 to 67420
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   game_id                   67421 non-null  int64
#  1   competition_id            67421 non-null  object
#  2   season                    67421 non-null  int64
#  3   round                     67421 non-null  object
#  4   date                      67421 non-null  object
#  5   home_club_id              67421 non-null  int64
#  6   away_club_id              67421 non-null  int64
#  7   home_club_goals           67421 non-null  int64
#  8   away_club_goals           67421 non-null  int64
#  9   home_club_position        47449 non-null  float64
#  10  away_club_position        47449 non-null  float64
#  11  home_club_manager_name    66675 non-null  object
#  12  away_club_manager_name    66675 non-null  object
# ...

# %%
df2 = pd.merge(clubs, df, left_on='domestic_competition_id', right_on='competition_id', how='inner')
df2
# Out:
#          club_id        club_code                            name_x  \
# 0            105  sv-darmstadt-98  Sportverein Darmstadt 1898 e. V.
# 1            105  sv-darmstadt-98  Sportverein Darmstadt 1898 e. V.
# 2            105  sv-darmstadt-98  Sportverein Darmstadt 1898 e. V.
# 3            105  sv-darmstadt-98  Sportverein Darmstadt 1898 e. V.
# 4            105  sv-darmstadt-98  Sportverein Darmstadt 1898 e. V.
# ...          ...              ...                               ...
# 1492001      347          fc-metz             Football Club de Metz
# 1492002      347          fc-metz             Football Club de Metz
# 1492003      347          fc-metz             Football Club de Metz
# 1492004      347          fc-metz             Football Club de Metz
# 1492005      347          fc-metz             Football Club de Metz
#
#         domestic_competition_id  total_market_value  squad_size  average_age  \
# ...

# %%
df2 = df2.drop(['total_market_value', 'coach_name'], axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1492006 entries, 0 to 1492005
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   club_id                   1492006 non-null  int64
#  1   club_code                 1492006 non-null  object
#  2   name_x                    1492006 non-null  object
#  3   domestic_competition_id   1492006 non-null  object
#  4   squad_size                1492006 non-null  int64
#  5   average_age               1387145 non-null  float64
#  6   foreigners_number         1492006 non-null  int64
#  7   foreigners_percentage     1357508 non-null  float64
#  8   national_team_players     1492006 non-null  int64
#  9   stadium_name              1492006 non-null  object
#  10  stadium_seats             1492006 non-null  int64
#  11  net_transfer_record       1492006 non-null  object
#  12  last_season               1492006 non-null  int64
# ...

# %%
df2['date'] = pd.to_datetime(df2['date'])

# %%
df2['date'].sort_values(ascending=True)
# Out:
# 1292309   2012-07-13
# 795888    2012-07-13
# 761072    2012-07-13
# 789744    2012-07-13
# 1332950   2012-07-13
#              ...
# 541271    2024-03-17
# 687847    2024-03-17
# 304316    2024-03-17
# 403652    2024-03-17
# 1035822   2024-03-17
# Name: date, Length: 1492006, dtype: datetime64[ns]

# %%
start_date = '2018-08-01'
end_date = '2024-12-31'
mask = (df2['date'] >= start_date) & (df2['date'] <= end_date)
df3 = df2.loc[mask]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 726179 entries, 123 to 1492005
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   club_id                   726179 non-null  int64
#  1   club_code                 726179 non-null  object
#  2   name_x                    726179 non-null  object
#  3   domestic_competition_id   726179 non-null  object
#  4   squad_size                726179 non-null  int64
#  5   average_age               675337 non-null  float64
#  6   foreigners_number         726179 non-null  int64
#  7   foreigners_percentage     660715 non-null  float64
#  8   national_team_players     726179 non-null  int64
#  9   stadium_name              726179 non-null  object
#  10  stadium_seats             726179 non-null  int64
#  11  net_transfer_record       726179 non-null  object
#  12  last_season               726179 non-null  int64
# ...

# %%
df3['date'].sort_values(ascending=True)
# Out:
# 776557    2018-08-03
# 1331742   2018-08-03
# 150359    2018-08-03
# 689187    2018-08-03
# 786797    2018-08-03
#              ...
# 1343928   2024-03-17
# 717359    2024-03-17
# 254237    2024-03-17
# 793096    2024-03-17
# 1238735   2024-03-17
# Name: date, Length: 726179, dtype: datetime64[ns]

# %%
df3['country_name'].unique()
# Out:
# array(['Germany', 'Russia', 'Turkey', 'Italy', 'England', 'Belgium',
#        'Denmark', 'Netherlands', 'Greece', 'Portugal', 'Scotland',
#        'Spain', 'Ukraine', 'France'], dtype=object)

# %%
#국가 지정 
desired_countries = ['Germany', 'Italy', 'England', 'Spain', 'France']
df4 = df3[df3['country_name'].isin(desired_countries)]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 351908 entries, 123 to 1492005
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   club_id                   351908 non-null  int64
#  1   club_code                 351908 non-null  object
#  2   name_x                    351908 non-null  object
#  3   domestic_competition_id   351908 non-null  object
#  4   squad_size                351908 non-null  int64
#  5   average_age               349719 non-null  float64
#  6   foreigners_number         351908 non-null  int64
#  7   foreigners_percentage     349719 non-null  float64
#  8   national_team_players     351908 non-null  int64
#  9   stadium_name              351908 non-null  object
#  10  stadium_seats             351908 non-null  int64
#  11  net_transfer_record       351908 non-null  object
#  12  last_season               351908 non-null  int64
# ...

# %%
df5 = df4[df4['competition_code'] == 'premier-league']
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78588 entries, 515077 to 675618
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   club_id                   78588 non-null  int64
#  1   club_code                 78588 non-null  object
#  2   name_x                    78588 non-null  object
#  3   domestic_competition_id   78588 non-null  object
#  4   squad_size                78588 non-null  int64
#  5   average_age               78588 non-null  float64
#  6   foreigners_number         78588 non-null  int64
#  7   foreigners_percentage     78588 non-null  float64
#  8   national_team_players     78588 non-null  int64
#  9   stadium_name              78588 non-null  object
#  10  stadium_seats             78588 non-null  int64
#  11  net_transfer_record       78588 non-null  object
#  12  last_season               78588 non-null  int64
# ...

# %%
game_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725287 entries, 0 to 725286
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   game_event_id     725287 non-null  object
#  1   date              725287 non-null  object
#  2   game_id           725287 non-null  int64
#  3   minute            725287 non-null  int64
#  4   type              725287 non-null  object
#  5   club_id           725287 non-null  int64
#  6   player_id         725287 non-null  int64
#  7   description       405843 non-null  object
#  8   player_in_id      439642 non-null  float64
#  9   player_assist_id  47030 non-null   float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 55.3+ MB

# %%
df6 = pd.merge(df5, game_events, on = 'game_id')

# %%
players
# Out:
#        player_id first_name     last_name                name  last_season  \
# 0             10   Miroslav         Klose      Miroslav Klose         2015
# 1             26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2             65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3             77        NaN         Lúcio               Lúcio         2012
# 4             80        Tom        Starke          Tom Starke         2017
# ...          ...        ...           ...                 ...          ...
# 30494    1201580      Yusuf        Yılmaz        Yusuf Yılmaz         2023
# 30495    1214946  Sid Ahmed      Aissaoui  Sid Ahmed Aissaoui         2023
# 30496    1225269      Erdem         Çalık         Erdem Çalık         2023
# 30497    1229924      Adama       Sidibeh       Adama Sidibeh         2023
# 30498    1240762    Araphat      Mohammed    Araphat Mohammed         2023
#
# ...

# %%
df7 = pd.merge(df6, players, on='player_id', how='left')

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811872 entries, 0 to 811871
# Data columns (total 75 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   club_id_x                             811872 non-null  int64
#  1   club_code                             811872 non-null  object
#  2   name_x                                811872 non-null  object
#  3   domestic_competition_id               811872 non-null  object
#  4   squad_size                            811872 non-null  int64
#  5   average_age                           811872 non-null  float64
#  6   foreigners_number                     811872 non-null  int64
#  7   foreigners_percentage                 811872 non-null  float64
#  8   national_team_players                 811872 non-null  int64
#  9   stadium_name                          811872 non-null  object
# ...

# %%
df7 = df7.drop(['url', 'image_url', 'first_name', 'last_name'], axis=1)

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811872 entries, 0 to 811871
# Data columns (total 71 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   club_id_x                             811872 non-null  int64
#  1   club_code                             811872 non-null  object
#  2   name_x                                811872 non-null  object
#  3   domestic_competition_id               811872 non-null  object
#  4   squad_size                            811872 non-null  int64
#  5   average_age                           811872 non-null  float64
#  6   foreigners_number                     811872 non-null  int64
#  7   foreigners_percentage                 811872 non-null  float64
#  8   national_team_players                 811872 non-null  int64
#  9   stadium_name                          811872 non-null  object
# ...

# %%
df7
# Out:
#         club_id_x             club_code                           name_x  \
# 0             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 1             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 2             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 3             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 4             148     tottenham-hotspur  Tottenham Hotspur Football Club
# ...           ...                   ...                              ...
# 811867        984  west-bromwich-albion             West Bromwich Albion
# 811868        984  west-bromwich-albion             West Bromwich Albion
# 811869        984  west-bromwich-albion             West Bromwich Albion
# 811870        984  west-bromwich-albion             West Bromwich Albion
# 811871        984  west-bromwich-albion             West Bromwich Albion
#
#        domestic_competition_id  squad_size  average_age  foreigners_number  \
# ...
