# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/t2023-m0093/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('Football.csv')

# %%
df
# Out:
#         club_id_x             club_code                           name_x  \
# 0             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 1             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 2             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 3             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 4             148     tottenham-hotspur  Tottenham Hotspur Football Club
# ...           ...                   ...                              ...
# 811867        984  west-bromwich-albion             West Bromwich Albion
# 811868        984  west-bromwich-albion             West Bromwich Albion
# 811869        984  west-bromwich-albion             West Bromwich Albion
# 811870        984  west-bromwich-albion             West Bromwich Albion
# 811871        984  west-bromwich-albion             West Bromwich Albion
#
#        domestic_competition_id  squad_size  average_age  foreigners_number  \
# ...

# %%
df.columns
# Out:
# Index(['club_id_x', 'club_code', 'name_x', 'domestic_competition_id',
#        'squad_size', 'average_age', 'foreigners_number',
#        'foreigners_percentage', 'national_team_players', 'stadium_name',
#        'stadium_seats', 'net_transfer_record', 'last_season_x', 'game_id',
#        'competition_id', 'season', 'round', 'date_x', 'home_club_id',
#        'away_club_id', 'home_club_goals', 'away_club_goals',
#        'home_club_position', 'away_club_position', 'home_club_manager_name',
#        'away_club_manager_name', 'stadium', 'attendance', 'referee',
#        'home_club_formation', 'away_club_formation', 'home_club_name',
#        'away_club_name', 'aggregate', 'competition_type', 'competition_code',
#        'name_y', 'sub_type', 'type_x', 'country_id', 'country_name',
#        'domestic_league_code', 'confederation', 'url_x',
#        'is_major_national_league', 'game_event_id', 'date_y', 'minute',
# ...

# %%
# url, image, firstname, last name,,, drop
df = df.drop(['url_x','url_y','image_url','first_name','last_name','competition_type','country_id','country_name'],axis=1)
df
# Out:
#         club_id_x             club_code                           name_x  \
# 0             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 1             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 2             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 3             148     tottenham-hotspur  Tottenham Hotspur Football Club
# 4             148     tottenham-hotspur  Tottenham Hotspur Football Club
# ...           ...                   ...                              ...
# 811867        984  west-bromwich-albion             West Bromwich Albion
# 811868        984  west-bromwich-albion             West Bromwich Albion
# 811869        984  west-bromwich-albion             West Bromwich Albion
# 811870        984  west-bromwich-albion             West Bromwich Albion
# 811871        984  west-bromwich-albion             West Bromwich Albion
#
#        domestic_competition_id  squad_size  average_age  foreigners_number  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811872 entries, 0 to 811871
# Data columns (total 70 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   club_id_x                             811872 non-null  int64
#  1   club_code                             811872 non-null  object
#  2   name_x                                811872 non-null  object
#  3   domestic_competition_id               811872 non-null  object
#  4   squad_size                            811872 non-null  int64
#  5   average_age                           811872 non-null  float64
#  6   foreigners_number                     811872 non-null  int64
#  7   foreigners_percentage                 811872 non-null  float64
#  8   national_team_players                 811872 non-null  int64
#  9   stadium_name                          811872 non-null  object
# ...

# %%
null_count = df.isnull().sum()
null_count
# Out:
# club_id_x                                    0
# club_code                                    0
# name_x                                       0
# domestic_competition_id                      0
# squad_size                                   0
#                                          ...
# agent_name                              227664
# current_club_domestic_competition_id       144
# current_club_name                          144
# market_value_in_eur                        180
# highest_market_value_in_eur                180
# Length: 70, dtype: int64

# %%
null_count.plot(rot=60)
# Out:
# <Axes: >

# %%
df_null_count = null_count.reset_index
df_null_count
# Out:
# <bound method Series.reset_index of club_id_x                                    0
# club_code                                    0
# name_x                                       0
# domestic_competition_id                      0
# squad_size                                   0
#                                          ...
# agent_name                              227664
# current_club_domestic_competition_id       144
# current_club_name                          144
# market_value_in_eur                        180
# highest_market_value_in_eur                180
# Length: 70, dtype: int64>

# %%
df[['home_club_goals','away_club_goals']].describe()
# 홈과 어웨이에서 평균적으로 0.3골 차이
# Out:
#        home_club_goals  away_club_goals
# count    811872.000000    811872.000000
# mean          1.739846         1.437877
# std           1.407814         1.294054
# min           0.000000         0.000000
# 25%           1.000000         0.000000
# 50%           2.000000         1.000000
# 75%           3.000000         2.000000
# max           9.000000         9.000000

# %%
df.describe(include='object')
# Out:
#                 club_code                           name_x  \
# count              811872                           811872
# unique                 36                               36
# top     tottenham-hotspur  Tottenham Hotspur Football Club
# freq                22552                            22552
#
#        domestic_competition_id               stadium_name net_transfer_record  \
# count                   811872                     811872              811872
# unique                       1                         36                  36
# top                        GB1  Tottenham Hotspur Stadium           €-151.40m
# freq                    811872                      22552               22552
#
#        competition_id        round      date_x home_club_manager_name  \
# count          811872       811872      811872                 811872
# unique              1           38         690                     80
# ...

# %%
df['stadium'].value_counts()
# Out:
# stadium
# Etihad Stadium                 42768
# Emirates Stadium               42480
# Anfield                        41904
# Old Trafford                   41148
# St James' Park                 40716
# Molineux Stadium               40500
# AMEX Stadium                   40284
# Stamford Bridge                39852
# London Stadium                 39708
# Goodison Park                  38088
# Selhurst Park                  36864
# Tottenham Hotspur Stadium      36216
# Villa Park                     33768
# St Mary's Stadium              33480
# King Power Stadium             32760
# Turf Moor                      31284
# Vitality Stadium               30096
# Craven Cottage                 29268
# Vicarage Road                  19764
# Elland Road                    18900
# Bramall Lane                   18468
# The City Ground                14832
# Brentford Community Stadium    12852
# Carrow Road                    12492
# Cardiff City Stadium            8352
# ...

# %%
df['referee'].value_counts()
# Out:
# referee
# Anthony Taylor       63828
# Michael Oliver       62064
# Paul Tierney         53892
# Craig Pawson         48312
# Stuart Attwell       45216
# Chris Kavanagh       42948
# Andre Marriner       36828
# Mike Dean            36720
# David Coote          36504
# Simon Hooper         36432
# Martin Atkinson      36288
# Jonathan Moss        35172
# Andrew Madley        33048
# Kevin Friend         32616
# Robert Jones         26136
# Peter Bankes         24192
# Graham Scott         23436
# Darren England       19620
# Jarred Gillett       18072
# John Brooks          17244
# Lee Mason            16128
# Michael Salisbury    13068
# Tim Robinson         10116
# Thomas Bramall        7416
# Lee Probert           7236
# Samuel Barrott        7056
# Tony Harrington       5760
# Roger East            4932
# Darren Bond           3780
# Josh Smith            2664
# Samuel Allison        1368
# Lewis Smith           1260
# Rebecca Welch         1116
# Bobby Madley           864
# ...

# %%
df['country_of_birth'].value_counts()
# Out:
# country_of_birth
# England         272880
# Brazil           62604
# France           61560
# Spain            36828
# Portugal         30996
#                  ...
# Kenya              180
# Iraq               144
# Saudi Arabia       108
# Haiti              108
# Costa Rica          36
# Name: count, Length: 89, dtype: int64

# %%
df['foot'].value_counts()
# Out:
# foot
# right    579168
# left     201492
# both      30096
# Name: count, dtype: int64

# %%
df['current_club_name'].value_counts()
# Out:
# current_club_name
# Newcastle United Football Club     43596
# Tottenham Hotspur Football Club    36504
# Liverpool Football Club            35928
# Arsenal Football Club              35352
# Fulham Football Club               34992
#                                    ...
# İstanbulspor A.Ş.                     36
# FK Ural Yekaterinburg                 36
# RCD Espanyol Barcelona                36
# CD Leganés                            36
# Associazione Calcio Monza             36
# Name: count, Length: 152, dtype: int64
